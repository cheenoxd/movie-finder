# %%
import numpy as np
import pandas as pd
import re
import nltk


movies = pd.read_csv("movie_data.csv")
movies
# Out:
#              Original Title       ID  \
# 0                   Red One   845781
# 1     Venom: The Last Dance   912649
# 2      Sonic the Hedgehog 3   939243
# 3     Mufasa: The Lion King   762509
# 4                   Moana 2  1241982
# ...                     ...      ...
# 9995                Tomcats    10646
# 9996            Airport '77     7227
# 9997               Rye Lane  1049638
# 9998             胸が鳴るのは君のせい   803279
# 9999       Alex Strangelove   511785
#
#                                             Genres  Adult  \
# 0                          Action, Fantasy, Comedy  False
# 1     Action, Science Fiction, Adventure, Thriller  False
# 2          Action, Science Fiction, Comedy, Family  False
# 3              Adventure, Family, Drama, Animation  False
# 4             Animation, Adventure, Family, Comedy  False
# ...                                            ...    ...
# 9995                               Comedy, Romance  False
# 9996            Action, Adventure, Drama, Thriller  False
# 9997                               Comedy, Romance  False
# 9998                                Romance, Drama  False
# 9999                                 Comedy, Drama  False
#
#                                                Overview  Rating  \
# 0     After Santa Claus (codename: Red One) is kidna...    70.2
# 1     Eddie and Venom are on the run. Hunted by both...    68.0
# 2     Sonic, Knuckles, and Tails reunite against a p...    78.0
# 3     Told in flashbacks, Mufasa is an orphaned cub,...    71.0
# 4     After receiving an unexpected call from her wa...    69.4
# ...                                                 ...     ...
# 9995  College buddies chip in and promise that the g...    51.0
# 9996  Flight 23 has crashed in the Bermuda Triangle ...    55.9
# 9997  Two twenty-somethings, both reeling from bad b...    71.0
# 9998  When Tsukasa was a middle school student, she ...    75.0
# 9999  Alex Truelove is on a quest to lose his virgin...    65.8
#
#       Runtime (Seconds)                                             Actors  \
# 0                  7440  Dwayne Johnson, Chris Evans, Lucy Liu, J.K. Si...
# 1                  6540  Tom Hardy, Chiwetel Ejiofor, Juno Temple, Clar...
# 2                  6600  Ben Schwartz, Jim Carrey, Keanu Reeves, Idris ...
# 3                  7080  Aaron Pierre, Kelvin Harrison Jr., Tiffany Boo...
# 4                  6000  Auliʻi Cravalho, Dwayne Johnson, Hualālai Chun...
# ...                 ...                                                ...
# 9995               5700  Jerry O'Connell, Shannon Elizabeth, Jake Busey...
# 9996               6840  Jack Lemmon, Lee Grant, Brenda Vaccaro, Joseph...
# 9997               4920  David Jonsson, Vivian Oparah, Poppy Allen-Quar...
# 9998               6240  Ukisho Hidaka, Sei Shiraishi, Mizuki Itagaki, ...
# 9999               5940  Daniel Doheny, Madeline Weinstein, Antonio Mar...
#
#                                              Characters              Director  \
# 0     Callum Drift, Jack O'Malley, Zoe, Nick, Mrs. C...           Jake Kasdan
# 1     Eddie Brock / Venom, General Rex Strickland, D...          Kelly Marcel
# 2     Sonic (voice), Dr. Robotnik / Gerald Robotnik,...           Jeff Fowler
# 3     Mufasa (voice), Taka (voice), Sarabi (voice), ...         Barry Jenkins
# 4     Moana (voice), Maui (voice), Moni (voice), Lot...  David G. Derrick Jr.
# ...                                                 ...                   ...
# 9995  Michael Delaney, Officer Natalie Parker, Kyle ...       Gregory Poirier
# 9996  Don Gallagher, Karen Wallace, Eve Clayton, Nic...         Jerry Jameson
# 9997                       Dom, Yas, Cass, Nathan, Eric    Raine Allen-Miller
# 9998  Arima Hayato, Shinohara Tsukasa, Hasebe Yasuhi...      Hiroto Takahashi
# 9999         Alex Truelove, Claire, Elliott, Dell, Josh         Craig Johnson
#
#      Certification
# 0            PG-13
# 1            PG-13
# 2               PG
# 3               PG
# 4               PG
# ...            ...
# 9995             R
# 9996            PG
# 9997             R
# 9998     Not Rated
# 9999             R
#
# [10000 rows x 11 columns]

# %%
## Process Data
## Clean up overviews
movies['clean_overview'] = movies['Overview'].fillna('')

# Clean up text: Convert to lowercase, remove non-alphanumeric characters, and trim spaces
movies['clean_overview'] = movies['clean_overview'].apply(
    lambda x: re.sub(r'[^a-z0-9]', ' ', x.lower()) if isinstance(x, str) else ''
)
movies['clean_overview'] = movies['clean_overview'].apply(
    lambda x: re.sub(r'\s+', ' ', x).strip()
)

print(movies['clean_overview'].head())
# Out:
# 0    after santa claus codename red one is kidnappe...
# 1    eddie and venom are on the run hunted by both ...
# 2    sonic knuckles and tails reunite against a pow...
# 3    told in flashbacks mufasa is an orphaned cub l...
# 4    after receiving an unexpected call from her wa...
# Name: clean_overview, dtype: object

# %%
# Tokenize Sentence

movies['clean_overview'] = movies['clean_overview'].apply(
    lambda x: ' '.join(x) if isinstance(x, list) else x
)

# Tokenize sentences
movies['clean_overview'] = movies['clean_overview'].apply(nltk.word_tokenize)
movies
# Out:
#              Original Title       ID  \
# 0                   Red One   845781
# 1     Venom: The Last Dance   912649
# 2      Sonic the Hedgehog 3   939243
# 3     Mufasa: The Lion King   762509
# 4                   Moana 2  1241982
# ...                     ...      ...
# 9995                Tomcats    10646
# 9996            Airport '77     7227
# 9997               Rye Lane  1049638
# 9998             胸が鳴るのは君のせい   803279
# 9999       Alex Strangelove   511785
#
#                                             Genres  Adult  \
# 0                          Action, Fantasy, Comedy  False
# 1     Action, Science Fiction, Adventure, Thriller  False
# 2          Action, Science Fiction, Comedy, Family  False
# 3              Adventure, Family, Drama, Animation  False
# 4             Animation, Adventure, Family, Comedy  False
# ...                                            ...    ...
# 9995                               Comedy, Romance  False
# 9996            Action, Adventure, Drama, Thriller  False
# 9997                               Comedy, Romance  False
# 9998                                Romance, Drama  False
# 9999                                 Comedy, Drama  False
#
#                                                Overview  Rating  \
# 0     After Santa Claus (codename: Red One) is kidna...    70.2
# 1     Eddie and Venom are on the run. Hunted by both...    68.0
# 2     Sonic, Knuckles, and Tails reunite against a p...    78.0
# 3     Told in flashbacks, Mufasa is an orphaned cub,...    71.0
# 4     After receiving an unexpected call from her wa...    69.4
# ...                                                 ...     ...
# 9995  College buddies chip in and promise that the g...    51.0
# 9996  Flight 23 has crashed in the Bermuda Triangle ...    55.9
# 9997  Two twenty-somethings, both reeling from bad b...    71.0
# 9998  When Tsukasa was a middle school student, she ...    75.0
# 9999  Alex Truelove is on a quest to lose his virgin...    65.8
#
#       Runtime (Seconds)                                             Actors  \
# 0                  7440  Dwayne Johnson, Chris Evans, Lucy Liu, J.K. Si...
# 1                  6540  Tom Hardy, Chiwetel Ejiofor, Juno Temple, Clar...
# 2                  6600  Ben Schwartz, Jim Carrey, Keanu Reeves, Idris ...
# 3                  7080  Aaron Pierre, Kelvin Harrison Jr., Tiffany Boo...
# 4                  6000  Auliʻi Cravalho, Dwayne Johnson, Hualālai Chun...
# ...                 ...                                                ...
# 9995               5700  Jerry O'Connell, Shannon Elizabeth, Jake Busey...
# 9996               6840  Jack Lemmon, Lee Grant, Brenda Vaccaro, Joseph...
# 9997               4920  David Jonsson, Vivian Oparah, Poppy Allen-Quar...
# 9998               6240  Ukisho Hidaka, Sei Shiraishi, Mizuki Itagaki, ...
# 9999               5940  Daniel Doheny, Madeline Weinstein, Antonio Mar...
#
#                                              Characters              Director  \
# 0     Callum Drift, Jack O'Malley, Zoe, Nick, Mrs. C...           Jake Kasdan
# 1     Eddie Brock / Venom, General Rex Strickland, D...          Kelly Marcel
# 2     Sonic (voice), Dr. Robotnik / Gerald Robotnik,...           Jeff Fowler
# 3     Mufasa (voice), Taka (voice), Sarabi (voice), ...         Barry Jenkins
# 4     Moana (voice), Maui (voice), Moni (voice), Lot...  David G. Derrick Jr.
# ...                                                 ...                   ...
# 9995  Michael Delaney, Officer Natalie Parker, Kyle ...       Gregory Poirier
# 9996  Don Gallagher, Karen Wallace, Eve Clayton, Nic...         Jerry Jameson
# 9997                       Dom, Yas, Cass, Nathan, Eric    Raine Allen-Miller
# 9998  Arima Hayato, Shinohara Tsukasa, Hasebe Yasuhi...      Hiroto Takahashi
# 9999         Alex Truelove, Claire, Elliott, Dell, Josh         Craig Johnson
#
#      Certification                                     clean_overview
# 0            PG-13  [after, santa, claus, codename, red, one, is, ...
# 1            PG-13  [eddie, and, venom, are, on, the, run, hunted,...
# 2               PG  [sonic, knuckles, and, tails, reunite, against...
# 3               PG  [told, in, flashbacks, mufasa, is, an, orphane...
# 4               PG  [after, receiving, an, unexpected, call, from,...
# ...            ...                                                ...
# 9995             R  [college, buddies, chip, in, and, promise, tha...
# 9996            PG  [flight, 23, has, crashed, in, the, bermuda, t...
# 9997             R  [two, twenty, somethings, both, reeling, from,...
# 9998     Not Rated  [when, tsukasa, was, a, middle, school, studen...
# 9999             R  [alex, truelove, is, on, a, quest, to, lose, h...
#
# [10000 rows x 12 columns]

# %%
# Remove Stop Words

# Ensure no extra appends
stop_words = nltk.corpus.stopwords.words('english')
overview = []

for sentence in movies['clean_overview']:
    temp = []
    for word in sentence:
        if word not in stop_words or len(word) >= 3:
            temp.append(word)
    overview.append(temp)

# %%
movies['clean_overview'] = overview
overview
# Out:
# [['after',
#   'santa',
#   'claus',
#   'codename',
#   'red',
#   'one',
#   'kidnapped',
#   'the',
#   'north',
#   'pole',
#   'head',
#   'security',
#   'must',
#   'team',
#   'with',
#   'the',
#   'world',
#   'most',
#   'infamous',
#   'tracker',
#   'globe',
#   'trotting',
#   'action',
#   'packed',
#   'mission',
#   'save',
#   'christmas'],
#  ['eddie',
#   'and',
#   'venom',
#   'are',
#   'the',
#   'run',
#   'hunted',
#   'both',
#   'their',
#   'worlds',
#   'and',
#   'with',
#   'the',
#   'net',
#   'closing',
#   'the',
#   'duo',
#   'are',
#   'forced',
#   'into',
#   'devastating',
#   'decision',
#   'that',
#   'will',
#   'bring',
#   'the',
#   'curtains',
#   'down',
#   'venom',
#   'and',
#   'eddie',
#   'last',
#   'dance'],
#  ['sonic',
#   'knuckles',
#   'and',
#   'tails',
#   'reunite',
#   'against',
#   'powerful',
#   'new',
#   'adversary',
#   'shadow',
#   'mysterious',
#   'villain',
#   'with',
#   'powers',
#   'unlike',
#   'anything',
#   'they',
#   'have',
#   'faced',
#   'before',
#   'with',
#   'their',
#   'abilities',
#   'outmatched',
#   'every',
#   'way',
#   'team',
#   'sonic',
#   'must',
#   'seek',
#   'out',
#   'unlikely',
#   'alliance',
#   'hopes',
#   'stopping',
#   'shadow',
#   'and',
#   'protecting',
#   'the',
#   'planet'],
#  ['told',
#   'flashbacks',
#   'mufasa',
#   'orphaned',
#   'cub',
#   'lost',
#   'and',
#   'alone',
#   'until',
#   'meets',
#   'sympathetic',
#   'lion',
#   'named',
#   'taka',
#   'the',
#   'heir',
#   'royal',
#   'bloodline',
#   'the',
#   'chance',
#   'meeting',
#   'sets',
#   'motion',
#   'journey',
#   'misfits',
#   'searching',
#   'for',
#   'their',
#   'destiny',
#   'and',
#   'working',
#   'together',
#   'evade',
#   'threatening',
#   'and',
#   'deadly',
#   'foe'],
#  ['after',
#   'receiving',
#   'unexpected',
#   'call',
#   'from',
#   'her',
#   'wayfinding',
#   'ancestors',
#   'moana',
#   'journeys',
#   'alongside',
#   'maui',
#   'and',
#   'new',
#   'crew',
#   'the',
#   'far',
#   'seas',
#   'oceania',
#   'and',
#   'into',
#   'dangerous',
#   'long',
#   'lost',
#   'waters',
#   'for',
#   'adventure',
#   'unlike',
#   'anything',
#   'she',
#   'ever',
#   'faced'],
#  ['years',
#   'after',
#   'witnessing',
#   'the',
#   'death',
#   'the',
#   'revered',
#   'hero',
#   'maximus',
#   'the',
#   'hands',
#   'his',
#   'uncle',
#   'lucius',
#   'forced',
#   'enter',
#   'the',
#   'colosseum',
#   'after',
#   'his',
#   'home',
#   'conquered',
#   'the',
#   'tyrannical',
#   'emperors',
#   'who',
#   'now',
#   'lead',
#   'rome',
#   'with',
#   'iron',
#   'fist',
#   'with',
#   'rage',
#   'his',
#   'heart',
#   'and',
#   'the',
#   'future',
#   'the',
#   'empire',
#   'stake',
#   'lucius',
#   'must',
#   'look',
#   'his',
#   'past',
#   'find',
#   'strength',
#   'and',
#   'honor',
#   'return',
#   'the',
#   'glory',
#   'rome',
#   'its',
#   'people'],
#  ['airport',
#   'security',
#   'officer',
#   'races',
#   'outsmart',
#   'mysterious',
#   'traveler',
#   'forcing',
#   'him',
#   'let',
#   'dangerous',
#   'item',
#   'slip',
#   'onto',
#   'christmas',
#   'eve',
#   'flight'],
#  ['during',
#   'the',
#   'united',
#   'states',
#   '2021',
#   'withdrawal',
#   'from',
#   'afghanistan',
#   'group',
#   'female',
#   'soldiers',
#   'posing',
#   'medical',
#   'relief',
#   'are',
#   'sent',
#   'back',
#   'rescue',
#   'group',
#   'kidnapped',
#   'teenagers',
#   'caught',
#   'between',
#   'isis',
#   'and',
#   'the',
#   'taliban'],
#  ['the',
#   'love',
#   'between',
#   'noah',
#   'and',
#   'nick',
#   'seems',
#   'unwavering',
#   'despite',
#   'their',
#   'parents',
#   'attempts',
#   'separate',
#   'them',
#   'but',
#   'his',
#   'job',
#   'and',
#   'her',
#   'entry',
#   'into',
#   'college',
#   'open',
#   'their',
#   'lives',
#   'new',
#   'relationships',
#   'that',
#   'will',
#   'shake',
#   'the',
#   'foundations',
#   'both',
#   'their',
#   'relationship',
#   'and',
#   'the',
#   'leister',
#   'family',
#   'itself'],
#  ['single',
#   'father',
#   'and',
#   'two',
#   'women',
#   'venture',
#   'from',
#   'the',
#   'safety',
#   'their',
#   'homes',
#   'face',
#   'monstrous',
#   'creatures',
#   'save',
#   'the',
#   'life',
#   'young',
#   'boy'],
#  ['aging',
#   'ex',
#   'boxer',
#   'gangster',
#   'working',
#   'muscle',
#   'for',
#   'boston',
#   'crime',
#   'boss',
#   'receives',
#   'upsetting',
#   'diagnosis',
#   'despite',
#   'faltering',
#   'memory',
#   'attempts',
#   'rectify',
#   'the',
#   'sins',
#   'his',
#   'past',
#   'and',
#   'reconnect',
#   'with',
#   'his',
#   'estranged',
#   'children',
#   'determined',
#   'leave',
#   'positive',
#   'legacy',
#   'for',
#   'his',
#   'grandson',
#   'but',
#   'the',
#   'criminal',
#   'underworld',
#   'isn',
#   'done',
#   'with',
#   'him',
#   'and',
#   'won',
#   'loosen',
#   'their',
#   'grip',
#   'willingly'],
#  ['largo',
#   'winch',
#   'devastated',
#   'the',
#   'kidnapping',
#   'his',
#   'son',
#   'realizes',
#   'that',
#   'finds',
#   'those',
#   'responsible',
#   'for',
#   'his',
#   'bankruptcy',
#   'maybe',
#   'see',
#   'his',
#   'son',
#   'again'],
#  ['noah',
#   'must',
#   'leave',
#   'her',
#   'city',
#   'boyfriend',
#   'and',
#   'friends',
#   'move',
#   'into',
#   'william',
#   'leister',
#   'mansion',
#   'the',
#   'flashy',
#   'and',
#   'wealthy',
#   'husband',
#   'her',
#   'mother',
#   'rafaela',
#   'proud',
#   'and',
#   'independent',
#   '17',
#   'year',
#   'old',
#   'noah',
#   'resists',
#   'living',
#   'mansion',
#   'surrounded',
#   'luxury',
#   'however',
#   'there',
#   'where',
#   'she',
#   'meets',
#   'nick',
#   'her',
#   'new',
#   'stepbrother',
#   'and',
#   'the',
#   'clash',
#   'their',
#   'strong',
#   'personalities',
#   'becomes',
#   'evident',
#   'from',
#   'the',
#   'very',
#   'beginning'],
#  ['after',
#   'shipwreck',
#   'intelligent',
#   'robot',
#   'called',
#   'roz',
#   'stranded',
#   'uninhabited',
#   'island',
#   'survive',
#   'the',
#   'harsh',
#   'environment',
#   'roz',
#   'bonds',
#   'with',
#   'the',
#   'island',
#   'animals',
#   'and',
#   'cares',
#   'for',
#   'orphaned',
#   'baby',
#   'goose'],
#  ['kraven',
#   'kravinoff',
#   'complex',
#   'relationship',
#   'with',
#   'his',
#   'ruthless',
#   'gangster',
#   'father',
#   'nikolai',
#   'starts',
#   'him',
#   'down',
#   'path',
#   'vengeance',
#   'with',
#   'brutal',
#   'consequences',
#   'motivating',
#   'him',
#   'become',
#   'not',
#   'only',
#   'the',
#   'greatest',
#   'hunter',
#   'the',
#   'world',
#   'but',
#   'also',
#   'one',
#   'its',
#   'most',
#   'feared'],
#  ['fading',
#   'celebrity',
#   'decides',
#   'use',
#   'black',
#   'market',
#   'drug',
#   'cell',
#   'replicating',
#   'substance',
#   'that',
#   'temporarily',
#   'creates',
#   'younger',
#   'better',
#   'version',
#   'herself'],
#  ['five',
#   'years',
#   'after',
#   'surviving',
#   'art',
#   'the',
#   'clown',
#   'halloween',
#   'massacre',
#   'sienna',
#   'and',
#   'jonathan',
#   'are',
#   'still',
#   'struggling',
#   'rebuild',
#   'their',
#   'shattered',
#   'lives',
#   'the',
#   'holiday',
#   'season',
#   'approaches',
#   'they',
#   'try',
#   'embrace',
#   'the',
#   'christmas',
#   'spirit',
#   'and',
#   'leave',
#   'the',
#   'horrors',
#   'the',
#   'past',
#   'behind',
#   'but',
#   'just',
#   'when',
#   'they',
#   'think',
#   'they',
#   'safe',
#   'art',
#   'returns',
#   'determined',
#   'turn',
#   'their',
#   'holiday',
#   'cheer',
#   'into',
#   'new',
#   'nightmare',
#   'the',
#   'festive',
#   'season',
#   'quickly',
#   'unravels',
#   'art',
#   'unleashes',
#   'his',
#   'twisted',
#   'brand',
#   'terror',
#   'proving',
#   'that',
#   'holiday',
#   'safe'],
#  ['young',
#   'sex',
#   'worker',
#   'from',
#   'brooklyn',
#   'gets',
#   'her',
#   'chance',
#   'cinderella',
#   'story',
#   'when',
#   'she',
#   'meets',
#   'and',
#   'impulsively',
#   'marries',
#   'the',
#   'son',
#   'oligarch',
#   'once',
#   'the',
#   'news',
#   'reaches',
#   'russia',
#   'her',
#   'fairytale',
#   'threatened',
#   'his',
#   'parents',
#   'set',
#   'out',
#   'get',
#   'the',
#   'marriage',
#   'annulled'],
#  ['the',
#   'grinch',
#   'decides',
#   'rob',
#   'whoville',
#   'christmas',
#   'but',
#   'dash',
#   'kindness',
#   'from',
#   'little',
#   'cindy',
#   'lou',
#   'who',
#   'and',
#   'her',
#   'family',
#   'may',
#   'enough',
#   'melt',
#   'his',
#   'heart'],
#  ['listless',
#   'wade',
#   'wilson',
#   'toils',
#   'away',
#   'civilian',
#   'life',
#   'with',
#   'his',
#   'days',
#   'the',
#   'morally',
#   'flexible',
#   'mercenary',
#   'deadpool',
#   'behind',
#   'him',
#   'but',
#   'when',
#   'his',
#   'homeworld',
#   'faces',
#   'existential',
#   'threat',
#   'wade',
#   'must',
#   'reluctantly',
#   'suit',
#   'again',
#   'with',
#   'even',
#   'more',
#   'reluctant',
#   'wolverine'],
#  ['two',
#   'young',
#   'missionaries',
#   'are',
#   'forced',
#   'prove',
#   'their',
#   'faith',
#   'when',
#   'they',
#   'knock',
#   'the',
#   'wrong',
#   'door',
#   'and',
#   'are',
#   'greeted',
#   'diabolical',
#   'mr',
#   'reed',
#   'becoming',
#   'ensnared',
#   'his',
#   'deadly',
#   'game',
#   'cat',
#   'and',
#   'mouse'],
#  ['armored',
#   'truck',
#   'security',
#   'guard',
#   'james',
#   'brody',
#   'working',
#   'with',
#   'his',
#   'son',
#   'casey',
#   'transporting',
#   'millions',
#   'dollars',
#   'between',
#   'banks',
#   'when',
#   'team',
#   'thieves',
#   'led',
#   'rook',
#   'orchestrate',
#   'takeover',
#   'their',
#   'truck',
#   'seize',
#   'the',
#   'riches',
#   'following',
#   'violent',
#   'car',
#   'chase',
#   'rook',
#   'soon',
#   'has',
#   'the',
#   'armored',
#   'truck',
#   'surrounded',
#   'and',
#   'james',
#   'and',
#   'casey',
#   'find',
#   'themselves',
#   'cornered',
#   'onto',
#   'decrepit',
#   'bridge'],
#  ['instead',
#   'flying',
#   'florida',
#   'with',
#   'his',
#   'folks',
#   'kevin',
#   'ends',
#   'alone',
#   'new',
#   'york',
#   'where',
#   'gets',
#   'hotel',
#   'room',
#   'with',
#   'his',
#   'dad',
#   'credit',
#   'card',
#   'despite',
#   'problems',
#   'from',
#   'clerk',
#   'and',
#   'meddling',
#   'bellboy',
#   'but',
#   'when',
#   'kevin',
#   'runs',
#   'into',
#   'his',
#   'old',
#   'nemeses',
#   'the',
#   'wet',
#   'bandits',
#   'determined',
#   'foil',
#   'their',
#   'plans',
#   'rob',
#   'toy',
#   'store',
#   'christmas',
#   'eve'],
#  ['when',
#   'kind',
#   'rabies',
#   'that',
#   'transforms',
#   'people',
#   'into',
#   'aggressive',
#   'creatures',
#   'spreads',
#   'across',
#   'the',
#   'planet',
#   'manel',
#   'isolates',
#   'himself',
#   'home',
#   'with',
#   'his',
#   'cat',
#   'relying',
#   'his',
#   'wits',
#   'survive',
#   'but',
#   'soon',
#   'they',
#   'must',
#   'go',
#   'out',
#   'search',
#   'food',
#   'land',
#   'and',
#   'sea',
#   'dodging',
#   'many',
#   'dangers'],
#  ['unforgettable',
#   'christmas',
#   'for',
#   'the',
#   'townsfolk',
#   'wellington',
#   'sea',
#   'when',
#   'the',
#   'worst',
#   'snowstorm',
#   'history',
#   'alters',
#   'everyone',
#   'plans',
#   'including',
#   'santa'],
#  ['suspicious',
#   'the',
#   'events',
#   'ensnaring',
#   'their',
#   'former',
#   'colleagues',
#   'nite',
#   'owl',
#   'and',
#   'silk',
#   'spectre',
#   'are',
#   'spurred',
#   'out',
#   'retirement',
#   'investigate',
#   'they',
#   'grapple',
#   'with',
#   'personal',
#   'ethics',
#   'inner',
#   'demons',
#   'and',
#   'society',
#   'turned',
#   'against',
#   'them',
#   'they',
#   'race',
#   'the',
#   'clock',
#   'uncover',
#   'deepening',
#   'plot',
#   'that',
#   'might',
#   'trigger',
#   'global',
#   'nuclear',
#   'war'],
#  ['about',
#   'embark',
#   'new',
#   'world',
#   'tour',
#   'global',
#   'pop',
#   'sensation',
#   'skye',
#   'riley',
#   'begins',
#   'experiencing',
#   'increasingly',
#   'terrifying',
#   'and',
#   'inexplicable',
#   'events',
#   'overwhelmed',
#   'the',
#   'escalating',
#   'horrors',
#   'and',
#   'the',
#   'pressures',
#   'fame',
#   'skye',
#   'forced',
#   'face',
#   'her',
#   'dark',
#   'past',
#   'regain',
#   'control',
#   'her',
#   'life',
#   'before',
#   'spirals',
#   'out',
#   'control'],
#  ['dallas',
#   'burdened',
#   'but',
#   'headstrong',
#   'dancer',
#   'determined',
#   'get',
#   'into',
#   'the',
#   'best',
#   'dance',
#   'school',
#   'the',
#   'country',
#   'her',
#   'late',
#   'mother',
#   'alma',
#   'mater',
#   'however',
#   'that',
#   'dream',
#   'suddenly',
#   'derailed',
#   'when',
#   'the',
#   'cheeky',
#   'yet',
#   'secretly',
#   'grieving',
#   'football',
#   'star',
#   'drayton',
#   'crashes',
#   'into',
#   'her',
#   'life',
#   'with',
#   'unique',
#   'story',
#   'his',
#   'own',
#   'will',
#   'the',
#   'two',
#   'them',
#   'able',
#   'grow',
#   'into',
#   'their',
#   'dreams',
#   'together',
#   'will',
#   'their',
#   'dreams',
#   'sidelined'],
#  ['gru',
#   'and',
#   'lucy',
#   'and',
#   'their',
#   'girls',
#   'margo',
#   'edith',
#   'and',
#   'agnes',
#   'welcome',
#   'new',
#   'member',
#   'the',
#   'gru',
#   'family',
#   'gru',
#   'jr',
#   'who',
#   'intent',
#   'tormenting',
#   'his',
#   'dad',
#   'gru',
#   'also',
#   'faces',
#   'new',
#   'nemesis',
#   'maxime',
#   'le',
#   'mal',
#   'and',
#   'his',
#   'femme',
#   'fatale',
#   'girlfriend',
#   'valentina',
#   'forcing',
#   'the',
#   'family',
#   'go',
#   'the',
#   'run'],
#  ['save',
#   'the',
#   'future',
#   'from',
#   'terrible',
#   'fate',
#   'marinette',
#   'becomes',
#   'chronobug',
#   'and',
#   'teams',
#   'with',
#   'bunnyx',
#   'defeat',
#   'mysterious',
#   'opponent',
#   'who',
#   'travels',
#   'through',
#   'time',
#   'who',
#   'this',
#   'new',
#   'supervillain',
#   'and',
#   'why',
#   'are',
#   'they',
#   'obsessed',
#   'with',
#   'exposing',
#   'marinette',
#   'secret',
#   'superhero',
#   'identity',
#   'marinette',
#   'only',
#   'hope',
#   'defeat',
#   'her',
#   'new',
#   'opponent',
#   'prevent',
#   'the',
#   'end',
#   'ladybug',
#   'and',
#   'time',
#   'itself'],
#  ['teenager',
#   'riley',
#   'mind',
#   'headquarters',
#   'undergoing',
#   'sudden',
#   'demolition',
#   'make',
#   'room',
#   'for',
#   'something',
#   'entirely',
#   'unexpected',
#   'new',
#   'emotions',
#   'joy',
#   'sadness',
#   'anger',
#   'fear',
#   'and',
#   'disgust',
#   'who',
#   'long',
#   'been',
#   'running',
#   'successful',
#   'operation',
#   'all',
#   'accounts',
#   'aren',
#   'sure',
#   'how',
#   'feel',
#   'when',
#   'anxiety',
#   'shows',
#   'and',
#   'looks',
#   'like',
#   'she',
#   'not',
#   'alone'],
#  ['the',
#   'land',
#   'oz',
#   'ostracized',
#   'and',
#   'misunderstood',
#   'green',
#   'skinned',
#   'elphaba',
#   'forced',
#   'share',
#   'room',
#   'with',
#   'the',
#   'popular',
#   'aristocrat',
#   'glinda',
#   'shiz',
#   'university',
#   'and',
#   'the',
#   'two',
#   'unlikely',
#   'friendship',
#   'tested',
#   'they',
#   'begin',
#   'fulfill',
#   'their',
#   'respective',
#   'destinies',
#   'glinda',
#   'the',
#   'good',
#   'and',
#   'the',
#   'wicked',
#   'witch',
#   'the',
#   'west'],
#  ['while',
#   'scavenging',
#   'the',
#   'deep',
#   'ends',
#   'derelict',
#   'space',
#   'station',
#   'group',
#   'young',
#   'space',
#   'colonizers',
#   'come',
#   'face',
#   'face',
#   'with',
#   'the',
#   'most',
#   'terrifying',
#   'life',
#   'form',
#   'the',
#   'universe'],
#  ['former',
#   'dea',
#   'agent',
#   'and',
#   'former',
#   'undercover',
#   'operative',
#   'revisit',
#   'their',
#   'romance',
#   'during',
#   'fateful',
#   'weekend',
#   'taipei',
#   'unaware',
#   'the',
#   'dangerous',
#   'consequences',
#   'their',
#   'past'],
#  ['the',
#   'untold',
#   'origin',
#   'story',
#   'optimus',
#   'prime',
#   'and',
#   'megatron',
#   'better',
#   'known',
#   'sworn',
#   'enemies',
#   'but',
#   'once',
#   'were',
#   'friends',
#   'bonded',
#   'like',
#   'brothers',
#   'who',
#   'changed',
#   'the',
#   'fate',
#   'cybertron',
#   'forever'],
#  ['the',
#   'near',
#   'future',
#   'decimated',
#   'earth',
#   'paul',
#   'and',
#   'his',
#   'twin',
#   'sons',
#   'face',
#   'terror',
#   'night',
#   'when',
#   'ferocious',
#   'creatures',
#   'awaken',
#   'when',
#   'paul',
#   'nearly',
#   'killed',
#   'the',
#   'boys',
#   'come',
#   'with',
#   'plan',
#   'for',
#   'survival',
#   'using',
#   'everything',
#   'their',
#   'father',
#   'taught',
#   'them',
#   'keep',
#   'him',
#   'alive'],
#  ['after',
#   'settling',
#   'green',
#   'hills',
#   'sonic',
#   'eager',
#   'prove',
#   'has',
#   'what',
#   'takes',
#   'true',
#   'hero',
#   'his',
#   'test',
#   'comes',
#   'when',
#   'dr',
#   'robotnik',
#   'returns',
#   'this',
#   'time',
#   'with',
#   'new',
#   'partner',
#   'knuckles',
#   'search',
#   'for',
#   'emerald',
#   'that',
#   'has',
#   'the',
#   'power',
#   'destroy',
#   'civilizations',
#   'sonic',
#   'teams',
#   'with',
#   'his',
#   'own',
#   'sidekick',
#   'tails',
#   'and',
#   'together',
#   'they',
#   'embark',
#   'globe',
#   'trotting',
#   'journey',
#   'find',
#   'the',
#   'emerald',
#   'before',
#   'falls',
#   'into',
#   'the',
#   'wrong',
#   'hands'],
#  ['couple',
#   'celebrates',
#   'their',
#   'son',
#   'birthday',
#   'the',
#   'middle',
#   'the',
#   'ocean',
#   'their',
#   'boat',
#   'violent',
#   'storm',
#   'hits',
#   'and',
#   'brings',
#   'hungry',
#   'creatures',
#   'from',
#   'the',
#   'depths',
#   'and',
#   'they',
#   'fight',
#   'for',
#   'their',
#   'survival'],
#  ['abie',
#   'mourns',
#   'after',
#   'the',
#   'death',
#   'michael',
#   'she',
#   'finds',
#   'solace',
#   'from',
#   'her',
#   'supposedly',
#   'soon',
#   'father',
#   'law',
#   'roldan',
#   'and',
#   'starts',
#   'falling',
#   'for',
#   'him',
#   'but',
#   'when',
#   'michael',
#   'returns',
#   'their',
#   'world',
#   'turns',
#   'upside',
#   'down'],
#  ['gothic',
#   'tale',
#   'obsession',
#   'between',
#   'haunted',
#   'young',
#   'woman',
#   'and',
#   'the',
#   'terrifying',
#   'vampire',
#   'infatuated',
#   'with',
#   'her',
#   'causing',
#   'untold',
#   'horror',
#   'its',
#   'wake'],
#  ['the',
#   'grinch',
#   'hatches',
#   'scheme',
#   'ruin',
#   'christmas',
#   'when',
#   'the',
#   'residents',
#   'whoville',
#   'plan',
#   'their',
#   'annual',
#   'holiday',
#   'celebration'],
#  ['after',
#   'the',
#   'death',
#   'emperor',
#   'marcus',
#   'aurelius',
#   'his',
#   'devious',
#   'son',
#   'takes',
#   'power',
#   'and',
#   'demotes',
#   'maximus',
#   'one',
#   'rome',
#   'most',
#   'capable',
#   'generals',
#   'who',
#   'marcus',
#   'preferred',
#   'eventually',
#   'maximus',
#   'forced',
#   'become',
#   'gladiator',
#   'and',
#   'battle',
#   'the',
#   'death',
#   'against',
#   'other',
#   'men',
#   'for',
#   'the',
#   'amusement',
#   'paying',
#   'audiences'],
#  ['secret',
#   'agents',
#   'mike',
#   'stan',
#   'and',
#   'chlo',
#   'tasked',
#   'with',
#   'retrieving',
#   'stolen',
#   'briefcase',
#   'discover',
#   'holds',
#   'secret',
#   'map',
#   'hidden',
#   'world',
#   'war',
#   'ii',
#   'treasures',
#   'betrayed',
#   'their',
#   'own',
#   'french',
#   'minister',
#   'defense',
#   'and',
#   'hunted',
#   'former',
#   'marine',
#   'vogel',
#   'the',
#   'team',
#   'faces',
#   'internal',
#   'conflicts',
#   'and',
#   'danger',
#   'alliances',
#   'shift',
#   'secrets',
#   'unravel',
#   'and',
#   'battles',
#   'ensue',
#   'they',
#   'must',
#   'thwart',
#   'vogel',
#   'plan',
#   'claim',
#   'the',
#   'treasures',
#   'setting',
#   'the',
#   'stage',
#   'for',
#   'international',
#   'treasure',
#   'hunt',
#   'filled',
#   'with',
#   'unexpected',
#   'twists',
#   'and',
#   'unresolved',
#   'romantic',
#   'entanglements'],
#  ['mickey',
#   'makes',
#   'magical',
#   'wish',
#   'that',
#   'every',
#   'day',
#   'could',
#   'christmas',
#   'but',
#   'winds',
#   'having',
#   'second',
#   'thoughts',
#   'when',
#   'his',
#   'wish',
#   'actually',
#   'comes',
#   'true'],
#  ['world',
#   'where',
#   'one',
#   'speaks',
#   'devout',
#   'female',
#   'hunts',
#   'down',
#   'young',
#   'woman',
#   'who',
#   'has',
#   'escaped',
#   'her',
#   'imprisonment',
#   'recaptured',
#   'its',
#   'ruthless',
#   'leaders',
#   'azrael',
#   'due',
#   'sacrificed',
#   'pacify',
#   'ancient',
#   'evil',
#   'deep',
#   'within',
#   'the',
#   'surrounding',
#   'wilderness'],
#  ['after',
#   'unsolved',
#   'diamond',
#   'heist',
#   'hard',
#   'nosed',
#   'cop',
#   'pursuit',
#   'his',
#   'key',
#   'suspect',
#   'turns',
#   'into',
#   'obsession',
#   'until',
#   'they',
#   'finally',
#   'face',
#   'each',
#   'other',
#   'and',
#   'the',
#   'truth'],
#  ['when',
#   'notorious',
#   'gang',
#   'bikers',
#   'recruits',
#   'her',
#   'brother',
#   'for',
#   'heist',
#   'former',
#   'motocross',
#   'champion',
#   'must',
#   'face',
#   'her',
#   'deepest',
#   'fears',
#   'keep',
#   'her',
#   'family',
#   'safe'],
#  ['2045',
#   'convicted',
#   'criminals',
#   'are',
#   'given',
#   'the',
#   'opportunity',
#   'compete',
#   'the',
#   'world',
#   '1',
#   'televised',
#   'sporting',
#   'event',
#   'arena',
#   'wars',
#   'they',
#   'must',
#   'survive',
#   '7',
#   'rooms',
#   'and',
#   '7',
#   'the',
#   'most',
#   'vicious',
#   'killers',
#   'the',
#   'country',
#   'they',
#   'win',
#   'they',
#   'regain',
#   'their',
#   'freedom'],
#  ['simba',
#   'idolizes',
#   'his',
#   'father',
#   'king',
#   'mufasa',
#   'and',
#   'takes',
#   'heart',
#   'his',
#   'own',
#   'royal',
#   'destiny',
#   'but',
#   'not',
#   'everyone',
#   'the',
#   'kingdom',
#   'celebrates',
#   'the',
#   'new',
#   'cub',
#   'arrival',
#   'scar',
#   'mufasa',
#   'brother',
#   'and',
#   'former',
#   'heir',
#   'the',
#   'throne',
#   'has',
#   'plans',
#   'his',
#   'own',
#   'the',
#   'battle',
#   'for',
#   'pride',
#   'rock',
#   'ravaged',
#   'with',
#   'betrayal',
#   'tragedy',
#   'and',
#   'drama',
#   'ultimately',
#   'resulting',
#   'simba',
#   'exile',
#   'with',
#   'help',
#   'from',
#   'curious',
#   'pair',
#   'newfound',
#   'friends',
#   'simba',
#   'will',
#   'have',
#   'figure',
#   'out',
#   'how',
#   'grow',
#   'and',
#   'take',
#   'back',
#   'what',
#   'rightfully',
#   'his'],
#  ['after',
#   'his',
#   'father',
#   'death',
#   'eric',
#   'zimmerman',
#   'travels',
#   'spain',
#   'oversee',
#   'his',
#   'company',
#   'branches',
#   'madrid',
#   'falls',
#   'for',
#   'judith',
#   'and',
#   'engage',
#   'intense',
#   'erotic',
#   'relationship',
#   'full',
#   'exploration',
#   'however',
#   'eric',
#   'fears',
#   'his',
#   'secret',
#   'may',
#   'end',
#   'their',
#   'affair'],
#  ['after',
#   'witnessing',
#   'his',
#   'girlfriend',
#   'murder',
#   'man',
#   'risks',
#   'everything',
#   'including',
#   'reality',
#   'itself',
#   'discover',
#   'the',
#   'truth'],
#  ['after',
#   'losing',
#   'his',
#   'drug',
#   'empire',
#   'ferry',
#   'bouman',
#   'has',
#   'found',
#   'measure',
#   'peace',
#   'away',
#   'from',
#   'brabant',
#   'criminal',
#   'underworld',
#   'until',
#   'his',
#   'past',
#   'catches',
#   'him'],
#  ['fatih',
#   'and',
#   'kumru',
#   'lawyer',
#   'from',
#   'different',
#   'cities',
#   'team',
#   'for',
#   'case',
#   'involving',
#   'cheating',
#   'spouse',
#   'they',
#   'spend',
#   '8',
#   'hours',
#   'racing',
#   'around',
#   'izmir',
#   'gathering',
#   'evidence',
#   'unexpectedly',
#   'altering',
#   'their',
#   'plans',
#   'and',
#   'lives'],
#  ['after',
#   'their',
#   'late',
#   'former',
#   'captain',
#   'framed',
#   'lowrey',
#   'and',
#   'burnett',
#   'try',
#   'clear',
#   'his',
#   'name',
#   'only',
#   'end',
#   'the',
#   'run',
#   'themselves'],
#  ['and',
#   'coming',
#   'chef',
#   'and',
#   'recent',
#   'divorc',
#   'e',
#   'find',
#   'their',
#   'lives',
#   'forever',
#   'changed',
#   'when',
#   'chance',
#   'encounter',
#   'brings',
#   'them',
#   'together',
#   'decade',
#   'spanning',
#   'deeply',
#   'moving',
#   'romance'],
#  ['with',
#   'his',
#   'wife',
#   'out',
#   'sick',
#   'struggling',
#   'father',
#   'brings',
#   'home',
#   'lifelike',
#   'ai',
#   'only',
#   'have',
#   'his',
#   'self',
#   'aware',
#   'new',
#   'help',
#   'want',
#   'everything',
#   'her',
#   'new',
#   'family',
#   'has',
#   'offer',
#   'like',
#   'the',
#   'affection',
#   'her',
#   'owner',
#   'and',
#   'she',
#   'kill',
#   'get'],
#  ['innocent',
#   'face',
#   'cup',
#   'breasts',
#   'and',
#   'perfect',
#   'intercourse',
#   'skills',
#   'son',
#   'this',
#   'not',
#   'your',
#   'girlfriend',
#   'anymore',
#   'but',
#   'your',
#   'mother',
#   'ki',
#   'ho',
#   'brings',
#   'yuki',
#   'from',
#   'japan',
#   'marry',
#   'her',
#   'however',
#   'starts',
#   'cheating',
#   'her',
#   'with',
#   'his',
#   'ex',
#   'girlfriend',
#   'korea',
#   'min',
#   'cheol',
#   'comforted',
#   'yuki',
#   'and',
#   'thought',
#   'her',
#   'his',
#   'daughter',
#   'law',
#   'but',
#   'one',
#   'day',
#   'realizes',
#   'looking',
#   'her',
#   'woman',
#   'the',
#   'end',
#   'yuki',
#   'and',
#   'min',
#   'cheol',
#   'have',
#   'intercourse',
#   'without',
#   'ki',
#   'ho',
#   'knowing'],
#  ['ancient',
#   'polynesia',
#   'when',
#   'terrible',
#   'curse',
#   'incurred',
#   'maui',
#   'reaches',
#   'the',
#   'island',
#   'impetuous',
#   'chieftain',
#   'his',
#   'willful',
#   'daughter',
#   'answers',
#   'the',
#   'ocean',
#   'call',
#   'seek',
#   'out',
#   'the',
#   'demigod',
#   'set',
#   'things',
#   'right'],
#  ['edmond',
#   'dantes',
#   'becomes',
#   'the',
#   'target',
#   'sinister',
#   'plot',
#   'and',
#   'arrested',
#   'his',
#   'wedding',
#   'day',
#   'for',
#   'crime',
#   'did',
#   'not',
#   'commit',
#   'after',
#   '14',
#   'years',
#   'the',
#   'island',
#   'prison',
#   'ch',
#   'teau',
#   'manages',
#   'daring',
#   'escape',
#   'now',
#   'rich',
#   'beyond',
#   'his',
#   'dreams',
#   'assumes',
#   'the',
#   'identity',
#   'the',
#   'count',
#   'monte',
#   'cristo',
#   'and',
#   'exacts',
#   'his',
#   'revenge',
#   'the',
#   'three',
#   'men',
#   'who',
#   'betrayed',
#   'him'],
#  ['over',
#   'decade',
#   'after',
#   'gates',
#   'connecting',
#   'worlds',
#   'appeared',
#   'awakening',
#   'hunters',
#   'with',
#   'superpowers',
#   'weakest',
#   'hunter',
#   'sung',
#   'jinwoo',
#   'encounters',
#   'double',
#   'dungeon',
#   'and',
#   'accepts',
#   'mysterious',
#   'quest',
#   'becoming',
#   'the',
#   'only',
#   'one',
#   'able',
#   'level',
#   'changing',
#   'his',
#   'fate',
#   'catch',
#   'recap',
#   'the',
#   'first',
#   'season',
#   'coupled',
#   'with',
#   'exclusive',
#   'sneak',
#   'peek',
#   'the',
#   'first',
#   'two',
#   'episodes',
#   'the',
#   'highly',
#   'anticipated',
#   'second',
#   'season',
#   'one',
#   'momentous',
#   'theatrical',
#   'fan',
#   'experience'],
#  ['mary',
#   'and',
#   'tom',
#   'are',
#   'parentless',
#   'irish',
#   'siblings',
#   'who',
#   'arrive',
#   'new',
#   'york',
#   'city',
#   'via',
#   'ocean',
#   'liner',
#   '1886',
#   'and',
#   'quickly',
#   'find',
#   'themselves',
#   'wild',
#   'cross',
#   'country',
#   'journey',
#   'aboard',
#   'transcontinental',
#   'orphan',
#   'train',
#   'where',
#   'they',
#   'meet',
#   'extraordinary',
#   'new',
#   'friend',
#   'who',
#   'will',
#   'change',
#   'their',
#   'lives',
#   'forever'],
#  ['likeable',
#   '6th',
#   'grader',
#   'liam',
#   'writes',
#   'santa',
#   'asking',
#   'him',
#   'prove',
#   'that',
#   'real',
#   'but',
#   'liam',
#   'dyslexic',
#   'and',
#   'accidentally',
#   'sends',
#   'his',
#   'letter',
#   'satan',
#   'instead',
#   'who',
#   'shows',
#   'liam',
#   'house',
#   'excited',
#   'have',
#   'his',
#   'first',
#   'fanboy',
#   'letter',
#   'and',
#   'wanting',
#   'little',
#   'liam',
#   'soul'],
#  ['after',
#   'mysterious',
#   'leader',
#   'imposes',
#   'his',
#   'law',
#   'brutal',
#   'system',
#   'vertical',
#   'cells',
#   'new',
#   'arrival',
#   'battles',
#   'against',
#   'dubious',
#   'food',
#   'distribution',
#   'method'],
#  ['operating',
#   'alone',
#   'the',
#   'field',
#   'for',
#   'more',
#   'than',
#   '20',
#   'years',
#   'cia',
#   'hitman',
#   'uses',
#   'the',
#   'help',
#   'wanted',
#   'section',
#   'the',
#   'newspapers',
#   'get',
#   'his',
#   'orders',
#   'from',
#   'the',
#   'agency',
#   'his',
#   'long',
#   'lost',
#   'daughter',
#   'now',
#   'uk',
#   'mi6',
#   'analyst',
#   'tracks',
#   'him',
#   'down',
#   'deliver',
#   'shocking',
#   'news',
#   'his',
#   'cia',
#   'boss',
#   'has',
#   'been',
#   'dead',
#   'for',
#   'years',
#   'and',
#   'the',
#   'division',
#   'long',
#   'since',
#   'shut',
#   'down',
#   'together',
#   'they',
#   'set',
#   'out',
#   'discover',
#   'whose',
#   'orders',
#   'been',
#   'executing'],
#  ['malik',
#   'young',
#   'parisian',
#   'hustler',
#   'discovers',
#   'that',
#   'his',
#   'stepfather',
#   'serge',
#   'famous',
#   'bank',
#   'robber',
#   'has',
#   'been',
#   'arrested',
#   'along',
#   'with',
#   'his',
#   'accomplices',
#   'during',
#   'the',
#   'trial',
#   'iris',
#   'one',
#   'the',
#   'accused',
#   'lawyers',
#   'ch',
#   'rif',
#   'requests',
#   'malik',
#   'accept',
#   'dangerous',
#   'heist',
#   'exchange',
#   'for',
#   'serge',
#   'and',
#   'her',
#   'client',
#   'liberty',
#   'malik',
#   'must',
#   'convince',
#   'and',
#   'reunite',
#   'ch',
#   'rif',
#   'former',
#   'partners',
#   'accomplish',
#   'this',
#   'high',
#   'risk',
#   'stickup'],
#  ['powered',
#   'with',
#   'incredible',
#   'speed',
#   'sonic',
#   'the',
#   'hedgehog',
#   'embraces',
#   'his',
#   'new',
#   'home',
#   'earth',
#   'that',
#   'until',
#   'sonic',
#   'sparks',
#   'the',
#   'attention',
#   'super',
#   'uncool',
#   'evil',
#   'genius',
#   'dr',
#   'robotnik',
#   'now',
#   'super',
#   'villain',
#   'vs',
#   'super',
#   'sonic',
#   'all',
#   'out',
#   'race',
#   'across',
#   'the',
#   'globe',
#   'stop',
#   'robotnik',
#   'from',
#   'using',
#   'sonic',
#   'unique',
#   'power',
#   'for',
#   'world',
#   'domination'],
#  ['claire',
#   'approached',
#   'the',
#   'father',
#   'her',
#   'murdered',
#   'childhood',
#   'friend',
#   'help',
#   'investigate',
#   'the',
#   'haunted',
#   'moor',
#   'believes',
#   'his',
#   'son',
#   'final',
#   'resting',
#   'place'],
#  ['po',
#   'gearing',
#   'become',
#   'the',
#   'spiritual',
#   'leader',
#   'his',
#   'valley',
#   'peace',
#   'but',
#   'also',
#   'needs',
#   'someone',
#   'take',
#   'his',
#   'place',
#   'dragon',
#   'warrior',
#   'such',
#   'will',
#   'train',
#   'new',
#   'kung',
#   'fu',
#   'practitioner',
#   'for',
#   'the',
#   'spot',
#   'and',
#   'will',
#   'encounter',
#   'villain',
#   'called',
#   'the',
#   'chameleon',
#   'who',
#   'conjures',
#   'villains',
#   'from',
#   'the',
#   'past'],
#  ['for',
#   'centuries',
#   'and',
#   'across',
#   'cultures',
#   'parents',
#   'have',
#   'warned',
#   'their',
#   'children',
#   'the',
#   'legendary',
#   'bagman',
#   'who',
#   'snatches',
#   'innocent',
#   'children',
#   'and',
#   'stuffs',
#   'them',
#   'into',
#   'his',
#   'vile',
#   'rotting',
#   'bag',
#   'never',
#   'seen',
#   'again',
#   'patrick',
#   'mckee',
#   'narrowly',
#   'escaped',
#   'such',
#   'encounter',
#   'boy',
#   'which',
#   'left',
#   'him',
#   'with',
#   'lasting',
#   'scars',
#   'throughout',
#   'his',
#   'adulthood',
#   'now',
#   'patrick',
#   'childhood',
#   'tormentor',
#   'has',
#   'returned',
#   'threatening',
#   'the',
#   'safety',
#   'his',
#   'wife',
#   'karina',
#   'and',
#   'son',
#   'jake'],
#  ['when',
#   'powerful',
#   'spell',
#   'turns',
#   'her',
#   'parents',
#   'into',
#   'giant',
#   'monsters',
#   'teenage',
#   'princess',
#   'must',
#   'journey',
#   'into',
#   'the',
#   'wild',
#   'reverse',
#   'the',
#   'curse',
#   'before',
#   'too',
#   'late'],
#  ['string',
#   'violent',
#   'robberies',
#   'the',
#   'pacific',
#   'northwest',
#   'leads',
#   'veteran',
#   'fbi',
#   'agent',
#   'into',
#   'domestic',
#   'terrorist',
#   'plot',
#   'overthrow',
#   'the',
#   'federal',
#   'government'],
#  ['harry',
#   'potter',
#   'has',
#   'lived',
#   'under',
#   'the',
#   'stairs',
#   'his',
#   'aunt',
#   'and',
#   'uncle',
#   'house',
#   'his',
#   'whole',
#   'life',
#   'but',
#   'his',
#   '11th',
#   'birthday',
#   'learns',
#   'powerful',
#   'wizard',
#   'with',
#   'place',
#   'waiting',
#   'for',
#   'him',
#   'the',
#   'hogwarts',
#   'school',
#   'witchcraft',
#   'and',
#   'wizardry',
#   'learns',
#   'harness',
#   'his',
#   'newfound',
#   'powers',
#   'with',
#   'the',
#   'help',
#   'the',
#   'school',
#   'kindly',
#   'headmaster',
#   'harry',
#   'uncovers',
#   'the',
#   'truth',
#   'about',
#   'his',
#   'parents',
#   'deaths',
#   'and',
#   'about',
#   'the',
#   'villain',
#   'who',
#   'blame'],
#  ['solitary',
#   'cat',
#   'displaced',
#   'great',
#   'flood',
#   'finds',
#   'refuge',
#   'boat',
#   'with',
#   'various',
#   'species',
#   'and',
#   'must',
#   'navigate',
#   'the',
#   'challenges',
#   'adapting',
#   'transformed',
#   'world',
#   'together'],
#  ['mara',
#   'ancient',
#   'pagan',
#   'spirit',
#   'hunts',
#   'group',
#   'teenagers',
#   'taking',
#   'their',
#   'body',
#   'parts',
#   'reborn',
#   'disillusioned',
#   'and',
#   'desperate',
#   'investigator',
#   'has',
#   'face',
#   'his',
#   'deepest',
#   'fears',
#   'save',
#   'the',
#   'teenagers'],
#  ['soulmates',
#   'eric',
#   'and',
#   'shelly',
#   'are',
#   'brutally',
#   'murdered',
#   'when',
#   'the',
#   'demons',
#   'her',
#   'dark',
#   'past',
#   'catch',
#   'with',
#   'them',
#   'given',
#   'the',
#   'chance',
#   'save',
#   'his',
#   'true',
#   'love',
#   'sacrificing',
#   'himself',
#   'eric',
#   'sets',
#   'out',
#   'seek',
#   'merciless',
#   'revenge',
#   'their',
#   'killers',
#   'traversing',
#   'the',
#   'worlds',
#   'the',
#   'living',
#   'and',
#   'the',
#   'dead',
#   'put',
#   'the',
#   'wrong',
#   'things',
#   'right'],
#  ['when',
#   'juan',
#   'young',
#   'gasoline',
#   'smuggler',
#   'forced',
#   'work',
#   'for',
#   'mysterious',
#   'organization',
#   'the',
#   'desert',
#   'bordering',
#   'colombia',
#   'and',
#   'venezuela',
#   'his',
#   'girlfriend',
#   'diana',
#   'embarks',
#   'journey',
#   'uncover',
#   'the',
#   'secrets',
#   'that',
#   'inhabit',
#   'this',
#   'man',
#   'land'],
#  ['driving',
#   'home',
#   'her',
#   'secluded',
#   'estate',
#   'after',
#   'meeting',
#   'local',
#   'bar',
#   'player',
#   'out',
#   'score',
#   'thinks',
#   'his',
#   'beautiful',
#   'mysterious',
#   'date',
#   'will',
#   'another',
#   'casual',
#   'hook',
#   'while',
#   'getting',
#   'acquainted',
#   'their',
#   'flirtation',
#   'turns',
#   'playful',
#   'sexy',
#   'and',
#   'sinister',
#   'hoping',
#   'get',
#   'lucky',
#   'his',
#   'luck',
#   'may',
#   'have',
#   'just',
#   'run',
#   'out'],
#  ['garfield',
#   'the',
#   'world',
#   'famous',
#   'monday',
#   'hating',
#   'lasagna',
#   'loving',
#   'indoor',
#   'cat',
#   'about',
#   'have',
#   'wild',
#   'outdoor',
#   'adventure',
#   'after',
#   'unexpected',
#   'reunion',
#   'with',
#   'his',
#   'long',
#   'lost',
#   'father',
#   'scruffy',
#   'street',
#   'cat',
#   'vic',
#   'garfield',
#   'and',
#   'his',
#   'canine',
#   'friend',
#   'odie',
#   'are',
#   'forced',
#   'from',
#   'their',
#   'perfectly',
#   'pampered',
#   'life',
#   'into',
#   'joining',
#   'vic',
#   'hilarious',
#   'high',
#   'stakes',
#   'heist'],
#  ['when',
#   'his',
#   'dysfunctional',
#   'family',
#   'clashes',
#   'over',
#   'the',
#   'holidays',
#   'young',
#   'max',
#   'disillusioned',
#   'and',
#   'turns',
#   'his',
#   'back',
#   'christmas',
#   'little',
#   'does',
#   'know',
#   'this',
#   'lack',
#   'festive',
#   'spirit',
#   'has',
#   'unleashed',
#   'the',
#   'wrath',
#   'krampus',
#   'demonic',
#   'force',
#   'ancient',
#   'evil',
#   'intent',
#   'punishing',
#   'non',
#   'believers'],
#  [],
#  ['follow',
#   'the',
#   'mythic',
#   'journey',
#   'paul',
#   'atreides',
#   'unites',
#   'with',
#   'chani',
#   'and',
#   'the',
#   'fremen',
#   'while',
#   'path',
#   'revenge',
#   'against',
#   'the',
#   'conspirators',
#   'who',
#   'destroyed',
#   'his',
#   'family',
#   'facing',
#   'choice',
#   'between',
#   'the',
#   'love',
#   'his',
#   'life',
#   'and',
#   'the',
#   'fate',
#   'the',
#   'known',
#   'universe',
#   'paul',
#   'endeavors',
#   'prevent',
#   'terrible',
#   'future',
#   'only',
#   'can',
#   'foresee'],
#  ['criminal',
#   'mastermind',
#   'mason',
#   'about',
#   'execute',
#   'the',
#   'score',
#   'lifetime',
#   'when',
#   'his',
#   'lover',
#   'and',
#   'key',
#   'member',
#   'his',
#   'crew',
#   'decker',
#   'takes',
#   'the',
#   'team',
#   'down',
#   'and',
#   'reveals',
#   'she',
#   'undercover',
#   'interpol',
#   'agent',
#   'heartbroken',
#   'mason',
#   'escapes',
#   'and',
#   'retires',
#   'from',
#   'the',
#   'life',
#   'crime',
#   'until',
#   'his',
#   'younger',
#   'brother',
#   'shawn',
#   'out',
#   'his',
#   'league',
#   'taking',
#   'big',
#   'bank',
#   'heist',
#   'all',
#   'his',
#   'own',
#   'mason',
#   'has',
#   'choice',
#   'left',
#   'but',
#   'come',
#   'the',
#   'rescue',
#   'while',
#   'interpol',
#   'brings',
#   'decker',
#   'hoping',
#   'unnerve',
#   'him',
#   'before',
#   'the',
#   'swat',
#   'teams',
#   'storm',
#   'the',
#   'bank',
#   'mason',
#   'must',
#   'use',
#   'every',
#   'tool',
#   'his',
#   'arsenal',
#   'not',
#   'only',
#   'escape',
#   'with',
#   'the',
#   'prize',
#   'but',
#   'also',
#   'the',
#   'love',
#   'his',
#   'life'],
#  ['while',
#   'struggling',
#   'with',
#   'his',
#   'dual',
#   'identity',
#   'arthur',
#   'fleck',
#   'not',
#   'only',
#   'stumbles',
#   'upon',
#   'true',
#   'love',
#   'but',
#   'also',
#   'finds',
#   'the',
#   'music',
#   'that',
#   'always',
#   'been',
#   'inside',
#   'him'],
#  ['due',
#   'sudden',
#   'deteriorating',
#   'weather',
#   'conditions',
#   'visibility',
#   'the',
#   'airport',
#   'bridge',
#   'severely',
#   'impaired',
#   'leaving',
#   'people',
#   'stranded',
#   'and',
#   'risk',
#   'the',
#   'bridge',
#   'collapsing',
#   'due',
#   'series',
#   'chain',
#   'collisions',
#   'and',
#   'explosions',
#   'amidst',
#   'the',
#   'chaos',
#   'the',
#   'canine',
#   'subjects',
#   'echo',
#   'from',
#   'the',
#   'military',
#   'experiment',
#   'project',
#   'silence',
#   'who',
#   'were',
#   'being',
#   'transported',
#   'secret',
#   'break',
#   'free',
#   'and',
#   'all',
#   'human',
#   'survivors',
#   'become',
#   'targets',
#   'relentless',
#   'attacks'],
#  ['while',
#   'serving',
#   'juror',
#   'high',
#   'profile',
#   'murder',
#   'trial',
#   'family',
#   'man',
#   'justin',
#   'kemp',
#   'finds',
#   'himself',
#   'struggling',
#   'with',
#   'serious',
#   'moral',
#   'dilemma',
#   'one',
#   'could',
#   'use',
#   'sway',
#   'the',
#   'jury',
#   'verdict',
#   'and',
#   'potentially',
#   'convict',
#   'free',
#   'the',
#   'accused',
#   'killer'],
#  ['investigative',
#   'journalist',
#   'eddie',
#   'brock',
#   'attempts',
#   'comeback',
#   'following',
#   'scandal',
#   'but',
#   'accidentally',
#   'becomes',
#   'the',
#   'host',
#   'venom',
#   'violent',
#   'super',
#   'powerful',
#   'alien',
#   'symbiote',
#   'soon',
#   'must',
#   'rely',
#   'his',
#   'newfound',
#   'powers',
#   'protect',
#   'the',
#   'world',
#   'from',
#   'shadowy',
#   'organization',
#   'looking',
#   'for',
#   'symbiote',
#   'their',
#   'own'],
#  ['after',
#   'discovering',
#   'she',
#   'can',
#   'see',
#   'everyone',
#   'imaginary',
#   'friends',
#   'girl',
#   'embarks',
#   'magical',
#   'adventure',
#   'reconnect',
#   'forgotten',
#   'imaginary',
#   'friends',
#   'with',
#   'their',
#   'kids'],
#  ['laura',
#   'and',
#   'massimo',
#   'are',
#   'back',
#   'and',
#   'hotter',
#   'than',
#   'ever',
#   'but',
#   'the',
#   'reunited',
#   'couple',
#   'new',
#   'beginning',
#   'complicated',
#   'massimo',
#   'family',
#   'ties',
#   'and',
#   'mysterious',
#   'man',
#   'who',
#   'enters',
#   'laura',
#   'life',
#   'win',
#   'her',
#   'heart',
#   'and',
#   'trust',
#   'any',
#   'cost'],
#  ['new',
#   'york',
#   'city',
#   'invaded',
#   'alien',
#   'creatures',
#   'who',
#   'hunt',
#   'sound',
#   'woman',
#   'named',
#   'sam',
#   'fights',
#   'survive',
#   'with',
#   'her',
#   'cat'],
#  ['real',
#   'life',
#   'young',
#   'couple',
#   'wim',
#   'and',
#   'floor',
#   'spend',
#   'afternoon',
#   'the',
#   'sunwashed',
#   'rooms',
#   'crumbling',
#   'home',
#   'belgium',
#   'unique',
#   'twist',
#   'this',
#   'artistic',
#   'erotic',
#   'documentary',
#   'edited',
#   'nearly',
#   'real',
#   'time',
#   'the',
#   'slowness',
#   'get',
#   'the',
#   'build',
#   'the',
#   'sweetness',
#   'and',
#   'the',
#   'sexiness',
#   'forget',
#   'about',
#   'fingersnapping',
#   'fast',
#   'editing',
#   'slow',
#   'where'],
#  ['while',
#   'working',
#   'case',
#   'interpreter',
#   'hearing',
#   'impaired',
#   'police',
#   'detective',
#   'must',
#   'confront',
#   'group',
#   'criminals',
#   'trying',
#   'eliminate',
#   'deaf',
#   'murder',
#   'witness',
#   'her',
#   'apartment',
#   'building'],
#  ['when',
#   'the',
#   'disappearance',
#   'children',
#   'and',
#   'bloody',
#   'murders',
#   'multiply',
#   'small',
#   'mountain',
#   'village',
#   'old',
#   'legend',
#   'shrouded',
#   'sulphur',
#   'reappears',
#   'commander',
#   'guardiano',
#   'and',
#   'captain',
#   'the',
#   'gendarmerie',
#   'de',
#   'rolan',
#   'are',
#   'forced',
#   'join',
#   'forces',
#   'uncover',
#   'the',
#   'truth'],
#  ['during',
#   'world',
#   'war',
#   'ii',
#   'the',
#   'us',
#   'army',
#   'only',
#   'all',
#   'black',
#   'all',
#   'women',
#   'battalion',
#   'takes',
#   'impossible',
#   'mission',
#   'sorting',
#   'through',
#   'three',
#   'year',
#   'backlog',
#   '17',
#   'million',
#   'pieces',
#   'mail',
#   'that',
#   'hadn',
#   'been',
#   'delivered',
#   'american',
#   'soldiers',
#   'and',
#   'finish',
#   'within',
#   'six',
#   'months'],
#  ['women',
#   'are',
#   'lucky',
#   'they',
#   'get',
#   'have',
#   'the',
#   'only',
#   'organ',
#   'the',
#   'human',
#   'body',
#   'dedicated',
#   'exclusively',
#   'for',
#   'pleasure',
#   'the',
#   'clitoris',
#   'this',
#   'humorous',
#   'and',
#   'instructive',
#   'animated',
#   'documentary',
#   'find',
#   'out',
#   'its',
#   'unrecognized',
#   'anatomy',
#   'and',
#   'its',
#   'unknown',
#   'herstory'],
#  ['buster',
#   'moon',
#   'dreams',
#   'star',
#   'studded',
#   'spectacle',
#   'set',
#   'michael',
#   'jackson',
#   'thriller',
#   'this',
#   'animated',
#   'short',
#   'featuring',
#   'characters',
#   'from',
#   'the',
#   'hit',
#   'sing',
#   'films'],
#  ['over',
#   'many',
#   'missions',
#   'and',
#   'against',
#   'impossible',
#   'odds',
#   'dom',
#   'toretto',
#   'and',
#   'his',
#   'family',
#   'have',
#   'outsmarted',
#   'out',
#   'nerved',
#   'and',
#   'outdriven',
#   'every',
#   'foe',
#   'their',
#   'path',
#   'now',
#   'they',
#   'confront',
#   'the',
#   'most',
#   'lethal',
#   'opponent',
#   'they',
#   'ever',
#   'faced',
#   'terrifying',
#   'threat',
#   'emerging',
#   'from',
#   'the',
#   'shadows',
#   'the',
#   'past',
#   'who',
#   'fueled',
#   'blood',
#   'revenge',
#   'and',
#   'who',
#   'determined',
#   'shatter',
#   'this',
#   'family',
#   'and',
#   'destroy',
#   'everything',
#   'and',
#   'everyone',
#   'that',
#   'dom',
#   'loves',
#   'forever'],
#  ['after',
#   'family',
#   'tragedy',
#   'three',
#   'generations',
#   'the',
#   'deetz',
#   'family',
#   'return',
#   'home',
#   'winter',
#   'river',
#   'still',
#   'haunted',
#   'betelgeuse',
#   'lydia',
#   'life',
#   'turned',
#   'upside',
#   'down',
#   'when',
#   'her',
#   'teenage',
#   'daughter',
#   'astrid',
#   'accidentally',
#   'opens',
#   'the',
#   'portal',
#   'the',
#   'afterlife'],
#  ['several',
#   'generations',
#   'following',
#   'caesar',
#   'reign',
#   'apes',
#   'now',
#   'the',
#   'dominant',
#   'species',
#   'live',
#   'harmoniously',
#   'while',
#   'humans',
#   'have',
#   'been',
#   'reduced',
#   'living',
#   'the',
#   'shadows',
#   'new',
#   'tyrannical',
#   'ape',
#   'leader',
#   'builds',
#   'his',
#   'empire',
#   'one',
#   'young',
#   'ape',
#   'undertakes',
#   'harrowing',
#   'journey',
#   'that',
#   'will',
#   'cause',
#   'him',
#   'question',
#   'all',
#   'known',
#   'about',
#   'the',
#   'past',
#   'and',
#   'make',
#   'choices',
#   'that',
#   'will',
#   'define',
#   'future',
#   'for',
#   'apes',
#   'and',
#   'humans',
#   'alike'],
#  ['after',
#   'twelve',
#   'years',
#   'playing',
#   'his',
#   'favorite',
#   'mmorpg',
#   'game',
#   'momonga',
#   'logs',
#   'for',
#   'the',
#   'last',
#   'time',
#   'only',
#   'find',
#   'himself',
#   'transported',
#   'into',
#   'its',
#   'world',
#   'playing',
#   'indefinitely',
#   'throughout',
#   'his',
#   'adventures',
#   'his',
#   'avatar',
#   'ascends',
#   'the',
#   'title',
#   'sorcerer',
#   'king',
#   'ains',
#   'ooal',
#   'gown',
#   'once',
#   'prosperous',
#   'but',
#   'now',
#   'the',
#   'brink',
#   'ruin',
#   'the',
#   'sacred',
#   'kingdom',
#   'enjoyed',
#   'years',
#   'peace',
#   'after',
#   'construction',
#   'enormous',
#   'wall',
#   'protecting',
#   'them',
#   'from',
#   'neighboring',
#   'invasions',
#   'but',
#   'one',
#   'day',
#   'this',
#   'comes',
#   'end',
#   'when',
#   'the',
#   'demon',
#   'emperor',
#   'jaldabaoth',
#   'arrives',
#   'with',
#   'army',
#   'villainous',
#   'demi',
#   'humans',
#   'fearing',
#   'invasion',
#   'their',
#   'own',
#   'lands',
#   'the',
#   'neighboring',
#   'territory',
#   'the',
#   'slane',
#   'theocracy',
#   'forced',
#   'beg',
#   'their',
#   'enemies',
#   'the',
#   'sorcerer',
#   'kingdom',
#   'for',
#   'help',
#   'heeding',
#   'the',
#   'call',
#   'momonga',
#   'now',
#   'known',
#   'the',
#   'sorcerer',
#   'king',
#   'ains',
#   'ooal',
#   'gown',
#   'rallies',
#   'the',
#   'sorcerer',
#   'kingdom',
#   'and',
#   'its',
#   'undead',
#   'army',
#   'join',
#   'the',
#   'fight',
#   'alongside',
#   'the',
#   'sacred',
#   'kingdom',
#   'and',
#   'the',
#   'slane',
#   'theocracy',
#   'hopes',
#   'defeat',
#   'the',
#   'demon',
#   'emperor'],
#  ['following',
#   'their',
#   'explosive',
#   'showdown',
#   'godzilla',
#   'and',
#   'kong',
#   'must',
#   'reunite',
#   'against',
#   'colossal',
#   'undiscovered',
#   'threat',
#   'hidden',
#   'within',
#   'our',
#   'world',
#   'challenging',
#   'their',
#   'very',
#   'existence',
#   'and',
#   'our',
#   'own'],
#  ['siblings',
#   'lucy',
#   'edmund',
#   'susan',
#   'and',
#   'peter',
#   'step',
#   'through',
#   'magical',
#   'wardrobe',
#   'and',
#   'find',
#   'the',
#   'land',
#   'narnia',
#   'there',
#   'they',
#   'discover',
#   'charming',
#   'once',
#   'peaceful',
#   'kingdom',
#   'that',
#   'has',
#   'been',
#   'plunged',
#   'into',
#   'eternal',
#   'winter',
#   'the',
#   'evil',
#   'white',
#   'witch',
#   'jadis',
#   'aided',
#   'the',
#   'wise',
#   'and',
#   'magnificent',
#   'lion',
#   'aslan',
#   'the',
#   'children',
#   'lead',
#   'narnia',
#   'into',
#   'spectacular',
#   'climactic',
#   'battle',
#   'free',
#   'the',
#   'witch',
#   'glacial',
#   'powers',
#   'forever'],
#  ['20',
#   'years',
#   'after',
#   'the',
#   'events',
#   'transmorphers',
#   'newer',
#   'more',
#   'advanced',
#   'species',
#   'alien',
#   'robot',
#   'descends',
#   'rebuilt',
#   'earth',
#   'threatening',
#   'once',
#   'again',
#   'destroy',
#   'the',
#   'planet'],
#  ['dominique',
#   'well',
#   'trained',
#   'assassin',
#   'flees',
#   'from',
#   'her',
#   'troubled',
#   'past',
#   'attempt',
#   'begin',
#   'new',
#   'life',
#   'south',
#   'america',
#   'however',
#   'she',
#   'soon',
#   'finds',
#   'herself',
#   'town',
#   'plagued',
#   'with',
#   'violence',
#   'and',
#   'corruption',
#   'facing',
#   'brutal',
#   'attacks',
#   'from',
#   'the',
#   'police',
#   'and',
#   'mafia',
#   'dominique',
#   'must',
#   'decide',
#   'whether',
#   'protect',
#   'herself',
#   'innocent',
#   'family',
#   'that',
#   'has',
#   'taken',
#   'her'],
#  ['pushpa',
#   'struggles',
#   'sustain',
#   'his',
#   'sandalwood',
#   'smuggling',
#   'business',
#   'the',
#   'face',
#   'tough',
#   'opposition',
#   'from',
#   'the',
#   'police',
#   'led',
#   'arch',
#   'rival',
#   'bhanwar',
#   'singh',
#   'shekhawat'],
#  ['fourteen',
#   'year',
#   'old',
#   'elias',
#   'increasingly',
#   'feels',
#   'like',
#   'outsider',
#   'his',
#   'village',
#   'when',
#   'meets',
#   'his',
#   'new',
#   'neighbour',
#   'the',
#   'same',
#   'age',
#   'alexander',
#   'elias',
#   'confronted',
#   'with',
#   'his',
#   'burgeoning',
#   'sexuality'],
#  ['19',
#   'year',
#   'old',
#   'linn',
#   'leaves',
#   'her',
#   'small',
#   'town',
#   'sweden',
#   'and',
#   'heads',
#   'for',
#   'los',
#   'angeles',
#   'with',
#   'the',
#   'aim',
#   'becoming',
#   'the',
#   'world',
#   'next',
#   'big',
#   'porn',
#   'star',
#   'but',
#   'the',
#   'road',
#   'her',
#   'goal',
#   'turns',
#   'out',
#   'bumpier',
#   'than',
#   'she',
#   'imagined'],
#  ['christmastime',
#   'and',
#   'the',
#   'griswolds',
#   'are',
#   'preparing',
#   'for',
#   'family',
#   'seasonal',
#   'celebration',
#   'but',
#   'things',
#   'never',
#   'run',
#   'smoothly',
#   'for',
#   'clark',
#   'his',
#   'wife',
#   'ellen',
#   'and',
#   'their',
#   'two',
#   'kids',
#   'clark',
#   'continual',
#   'bad',
#   'luck',
#   'worsened',
#   'his',
#   'obnoxious',
#   'family',
#   'guests',
#   'but',
#   'manages',
#   'keep',
#   'going',
#   'knowing',
#   'that',
#   'his',
#   'christmas',
#   'bonus',
#   'due',
#   'soon'],
#  ['the',
#   'adventures',
#   'group',
#   'explorers',
#   'who',
#   'make',
#   'use',
#   'newly',
#   'discovered',
#   'wormhole',
#   'surpass',
#   'the',
#   'limitations',
#   'human',
#   'space',
#   'travel',
#   'and',
#   'conquer',
#   'the',
#   'vast',
#   'distances',
#   'involved',
#   'interstellar',
#   'voyage'],
#  ['after',
#   'the',
#   'unexpected',
#   'death',
#   'the',
#   'pope',
#   'cardinal',
#   'lawrence',
#   'tasked',
#   'with',
#   'managing',
#   'the',
#   'covert',
#   'and',
#   'ancient',
#   'ritual',
#   'electing',
#   'new',
#   'one',
#   'sequestered',
#   'the',
#   'vatican',
#   'with',
#   'the',
#   'catholic',
#   'church',
#   'most',
#   'powerful',
#   'leaders',
#   'until',
#   'the',
#   'process',
#   'complete',
#   'lawrence',
#   'finds',
#   'himself',
#   'the',
#   'center',
#   'conspiracy',
#   'that',
#   'could',
#   'lead',
#   'its',
#   'downfall'],
#  ['top',
#   'level',
#   'cia',
#   'agent',
#   'avery',
#   'graves',
#   'blackmailed',
#   'terrorists',
#   'into',
#   'betraying',
#   'her',
#   'own',
#   'country',
#   'save',
#   'her',
#   'kidnapped',
#   'husband',
#   'cut',
#   'off',
#   'from',
#   'her',
#   'team',
#   'she',
#   'turns',
#   'her',
#   'underworld',
#   'contacts',
#   'survive',
#   'and',
#   'help',
#   'locate',
#   'the',
#   'coveted',
#   'intelligence',
#   'that',
#   'the',
#   'kidnappers',
#   'want'],
#  ['grieving',
#   'woman',
#   'secluded',
#   'forest',
#   'encounters',
#   'killer',
#   'who',
#   'injects',
#   'her',
#   'with',
#   'paralytic',
#   'drug',
#   'her',
#   'body',
#   'shuts',
#   'down',
#   'her',
#   'fight',
#   'for',
#   'survival',
#   'begins'],
#  ['while',
#   'kamp',
#   'koral',
#   'for',
#   'reunion',
#   'spongebob',
#   'and',
#   'the',
#   'gang',
#   'are',
#   'stalked',
#   'mysterious',
#   'figure',
#   'lurking',
#   'the',
#   'shadows',
#   'campers',
#   'start',
#   'disappearing',
#   'one',
#   'one'],
#  ['jeong',
#   'hee',
#   'was',
#   'living',
#   'with',
#   'man',
#   'due',
#   'de',
#   'facto',
#   'marriage',
#   'one',
#   'day',
#   'her',
#   'daughter',
#   'dam',
#   'hoi',
#   'returned',
#   'from',
#   'her',
#   'study',
#   'abroad',
#   'dam',
#   'hoi',
#   'always',
#   'wears',
#   'leggings',
#   'the',
#   'soon',
#   'stepdad',
#   'byeong',
#   'min',
#   'who',
#   'usually',
#   'fan',
#   'leggings',
#   'pays',
#   'attention',
#   'her',
#   'daughter',
#   'clothes',
#   'jeong',
#   'hee',
#   'noticed',
#   'she',
#   'also',
#   'started',
#   'wearing',
#   'leggings',
#   'distract',
#   'her',
#   'young',
#   'prospective',
#   'husband'],
#  ['group',
#   'young',
#   'activists',
#   'set',
#   'out',
#   'make',
#   'environmental',
#   'statement',
#   'vandalizing',
#   'home',
#   'superstore',
#   'closes',
#   'but',
#   'their',
#   'plan',
#   'goes',
#   'terribly',
#   'wrong',
#   'when',
#   'they',
#   'become',
#   'trapped',
#   'inside',
#   'and',
#   'must',
#   'face',
#   'deranged',
#   'security',
#   'guard',
#   'with',
#   'gruesome',
#   'passion',
#   'for',
#   'primitive',
#   'hunting',
#   'the',
#   'night',
#   'fills',
#   'with',
#   'violence',
#   'and',
#   'terror',
#   'the',
#   'teenagers',
#   'find',
#   'themselves',
#   'desperate',
#   'fight',
#   'for',
#   'their',
#   'lives'],
#  ['when',
#   'top',
#   'hitman',
#   'joe',
#   'flood',
#   'diagnosed',
#   'with',
#   'terminal',
#   'illness',
#   'decides',
#   'take',
#   'matters',
#   'into',
#   'his',
#   'own',
#   'hands',
#   'taking',
#   'hit',
#   'out',
#   'himself',
#   'but',
#   'when',
#   'the',
#   'very',
#   'hitmen',
#   'hired',
#   'also',
#   'target',
#   'his',
#   'ex',
#   'girlfriend',
#   'must',
#   'fend',
#   'off',
#   'army',
#   'assassin',
#   'colleagues',
#   'and',
#   'win',
#   'back',
#   'the',
#   'love',
#   'his',
#   'life',
#   'before',
#   'too',
#   'late'],
#  ['after',
#   'reuniting',
#   'with',
#   'gwen',
#   'stacy',
#   'brooklyn',
#   'full',
#   'time',
#   'friendly',
# ...
#   'performance',
#   'driver',
#   'they',
#   'ever',
#   'encountered',
#   'his',
#   'forsaken',
#   'brother'],
#  ['five',
#   'years',
#   'from',
#   'when',
#   'joy',
#   'said',
#   'goodbye',
#   'ethan',
#   'and',
#   'hong',
#   'kong',
#   'pursue',
#   'her',
#   'dreams',
#   'canada',
#   'after',
#   'fighting',
#   'for',
#   'their',
#   'love',
#   'conquer',
#   'the',
#   'time',
#   'distance',
#   'and',
#   'global',
#   'shutdown',
#   'that',
#   'kept',
#   'them',
#   'apart',
#   'joy',
#   'and',
#   'ethan',
#   'meet',
#   'again',
#   'canada',
#   'but',
#   'realize',
#   'that',
#   'they',
#   'have',
#   'also',
#   'changed',
#   'lot',
#   'individually'],
#  ['rory',
#   'and',
#   'cobby',
#   'are',
#   'unlikely',
#   'partners',
#   'thrown',
#   'together',
#   'for',
#   'heist',
#   'but',
#   'when',
#   'goes',
#   'awry',
#   'they',
#   'team',
#   'outrun',
#   'police',
#   'backward',
#   'bureaucrats',
#   'and',
#   'vengeful',
#   'crime',
#   'boss'],
#  ['man',
#   'cub',
#   'named',
#   'mowgli',
#   'fostered',
#   'wolves',
#   'after',
#   'threat',
#   'from',
#   'the',
#   'tiger',
#   'shere',
#   'khan',
#   'mowgli',
#   'forced',
#   'flee',
#   'the',
#   'jungle',
#   'which',
#   'embarks',
#   'journey',
#   'self',
#   'discovery',
#   'with',
#   'the',
#   'help',
#   'the',
#   'panther',
#   'bagheera',
#   'and',
#   'the',
#   'free',
#   'spirited',
#   'bear',
#   'baloo'],
#  ['the',
#   'enigmatic',
#   'resurrection',
#   'rampage',
#   'and',
#   'retribution',
#   'undead',
#   'monster',
#   'remote',
#   'wilderness',
#   'unleashes',
#   'iconic',
#   'new',
#   'killer',
#   'after',
#   'locket',
#   'removed',
#   'from',
#   'collapsed',
#   'fire',
#   'tower',
#   'that',
#   'entombed',
#   'its',
#   'rotting',
#   'corpse'],
#  ['man',
#   'searches',
#   'for',
#   'his',
#   'father',
#   'pedro',
#   'p',
#   'ramo',
#   'town',
#   'doomed',
#   'violence',
#   'and',
#   'the',
#   'fury',
#   'frustrated',
#   'love'],
#  ['when',
#   'young',
#   'boy',
#   'begins',
#   'behaving',
#   'strangely',
#   'shocking',
#   'truths',
#   'emerge',
#   'the',
#   'story',
#   'unfolds',
#   'through',
#   'the',
#   'eyes',
#   'his',
#   'single',
#   'mother',
#   'teacher',
#   'who',
#   'believed',
#   'responsible',
#   'and',
#   'the',
#   'child',
#   'himself'],
#  ['while',
#   'under',
#   'heavily',
#   'armed',
#   'guard',
#   'the',
#   'dangerous',
#   'convicts',
#   'aboard',
#   'cargo',
#   'ship',
#   'unite',
#   'coordinated',
#   'escape',
#   'attempt',
#   'that',
#   'soon',
#   'escalates',
#   'into',
#   'bloody',
#   'all',
#   'out',
#   'riot',
#   'but',
#   'the',
#   'fugitives',
#   'continue',
#   'their',
#   'brutal',
#   'campaign',
#   'terror',
#   'they',
#   'soon',
#   'discover',
#   'that',
#   'not',
#   'even',
#   'the',
#   'most',
#   'vicious',
#   'among',
#   'them',
#   'safe',
#   'from',
#   'the',
#   'horror',
#   'they',
#   'unknowingly',
#   'unleashed',
#   'from',
#   'the',
#   'darkness',
#   'below',
#   'deck'],
#  ['the',
#   'true',
#   'story',
#   'photographer',
#   'elizabeth',
#   'lee',
#   'miller',
#   'fashion',
#   'model',
#   'who',
#   'became',
#   'acclaimed',
#   'war',
#   'correspondent',
#   'for',
#   'vogue',
#   'magazine',
#   'during',
#   'world',
#   'war',
#   'ii'],
#  ['super',
#   'hero',
#   'partners',
#   'scott',
#   'lang',
#   'and',
#   'hope',
#   'van',
#   'dyne',
#   'along',
#   'with',
#   'with',
#   'hope',
#   'parents',
#   'janet',
#   'van',
#   'dyne',
#   'and',
#   'hank',
#   'pym',
#   'and',
#   'scott',
#   'daughter',
#   'cassie',
#   'lang',
#   'find',
#   'themselves',
#   'exploring',
#   'the',
#   'quantum',
#   'realm',
#   'interacting',
#   'with',
#   'strange',
#   'new',
#   'creatures',
#   'and',
#   'embarking',
#   'adventure',
#   'that',
#   'will',
#   'push',
#   'them',
#   'beyond',
#   'the',
#   'limits',
#   'what',
#   'they',
#   'thought',
#   'possible'],
#  ['when',
#   'the',
#   'ruthless',
#   'forces',
#   'the',
#   'motherworld',
#   'threaten',
#   'quiet',
#   'farming',
#   'village',
#   'distant',
#   'moon',
#   'mysterious',
#   'outsider',
#   'becomes',
#   'its',
#   'best',
#   'hope',
#   'for',
#   'survival'],
#  ['broke',
#   'and',
#   'desperate',
#   'need',
#   'update',
#   'her',
#   'portfolio',
#   'new',
#   'york',
#   'city',
#   'model',
#   'katie',
#   'calls',
#   'number',
#   'from',
#   'tear',
#   'off',
#   'flyer',
#   'offering',
#   'free',
#   'photos',
#   'but',
#   'this',
#   'innocent',
#   'attempt',
#   'quickly',
#   'turns',
#   'into',
#   'unthinkable',
#   'kidnapping',
#   'nightmare',
#   'where',
#   'she',
#   'ripped',
#   'away',
#   'from',
#   'everyone',
#   'and',
#   'everything',
#   'she',
#   'knows'],
#  ['rick',
#   'and',
#   'evelyn',
#   'connell',
#   'along',
#   'with',
#   'their',
#   '8',
#   'year',
#   'old',
#   'son',
#   'alex',
#   'discover',
#   'the',
#   'key',
#   'the',
#   'legendary',
#   'scorpion',
#   'king',
#   'might',
#   'the',
#   'fabled',
#   'bracelet',
#   'anubis',
#   'unfortunately',
#   'newly',
#   'resurrected',
#   'imhotep',
#   'has',
#   'designs',
#   'the',
#   'bracelet',
#   'well',
#   'and',
#   'isn',
#   'above',
#   'kidnapping',
#   'its',
#   'new',
#   'bearer',
#   'alex',
#   'gain',
#   'control',
#   'anubis',
#   'otherworldly',
#   'army'],
#  ['when',
#   'his',
#   'family',
#   'moves',
#   'from',
#   'their',
#   'home',
#   'berlin',
#   'strange',
#   'new',
#   'house',
#   'poland',
#   'young',
#   'bruno',
#   'befriends',
#   'shmuel',
#   'boy',
#   'who',
#   'lives',
#   'the',
#   'other',
#   'side',
#   'the',
#   'fence',
#   'where',
#   'everyone',
#   'seems',
#   'wearing',
#   'striped',
#   'pajamas',
#   'unaware',
#   'shmuel',
#   'fate',
#   'jewish',
#   'prisoner',
#   'the',
#   'role',
#   'his',
#   'own',
#   'nazi',
#   'father',
#   'plays',
#   'his',
#   'imprisonment',
#   'bruno',
#   'embarks',
#   'dangerous',
#   'journey',
#   'inside',
#   'the',
#   'camp',
#   'walls'],
#  ['young',
#   'peruvian',
#   'bear',
#   'travels',
#   'london',
#   'search',
#   'new',
#   'home',
#   'finding',
#   'himself',
#   'lost',
#   'and',
#   'alone',
#   'paddington',
#   'station',
#   'meets',
#   'the',
#   'kindly',
#   'brown',
#   'family'],
#  ['alana',
#   'discover',
#   'the',
#   'truth',
#   'about',
#   'her',
#   'origin',
#   'she',
#   'not',
#   'ordinary',
#   'human',
#   'being',
#   'she',
#   'may',
#   'the',
#   'gift',
#   'for',
#   'humanity',
#   'and',
#   'become',
#   'its',
#   'protector',
#   'sri',
#   'asih',
#   'destruction',
#   'she',
#   'can',
#   'control',
#   'her',
#   'anger'],
#  ['billy',
#   'batson',
#   'and',
#   'his',
#   'foster',
#   'siblings',
#   'who',
#   'transform',
#   'into',
#   'superheroes',
#   'saying',
#   'shazam',
#   'are',
#   'forced',
#   'get',
#   'back',
#   'into',
#   'action',
#   'and',
#   'fight',
#   'the',
#   'daughters',
#   'atlas',
#   'who',
#   'they',
#   'must',
#   'stop',
#   'from',
#   'using',
#   'weapon',
#   'that',
#   'could',
#   'destroy',
#   'the',
#   'world'],
#  ['beatrice',
#   'prior',
#   'must',
#   'confront',
#   'her',
#   'inner',
#   'demons',
#   'and',
#   'continue',
#   'her',
#   'fight',
#   'against',
#   'powerful',
#   'alliance',
#   'which',
#   'threatens',
#   'tear',
#   'her',
#   'society',
#   'apart'],
#  ['aibileen',
#   'clark',
#   'middle',
#   'aged',
#   'african',
#   'american',
#   'maid',
#   'who',
#   'has',
#   'spent',
#   'her',
#   'life',
#   'raising',
#   'white',
#   'children',
#   'and',
#   'has',
#   'recently',
#   'lost',
#   'her',
#   'only',
#   'son',
#   'minny',
#   'jackson',
#   'african',
#   'american',
#   'maid',
#   'who',
#   'has',
#   'often',
#   'offended',
#   'her',
#   'employers',
#   'despite',
#   'her',
#   'family',
#   'struggles',
#   'with',
#   'money',
#   'and',
#   'her',
#   'desperate',
#   'need',
#   'for',
#   'jobs',
#   'and',
#   'eugenia',
#   'skeeter',
#   'phelan',
#   'young',
#   'white',
#   'woman',
#   'who',
#   'has',
#   'recently',
#   'moved',
#   'back',
#   'home',
#   'after',
#   'graduating',
#   'college',
#   'find',
#   'out',
#   'her',
#   'childhood',
#   'maid',
#   'has',
#   'mysteriously',
#   'disappeared',
#   'these',
#   'three',
#   'stories',
#   'intertwine',
#   'explain',
#   'how',
#   'life',
#   'jackson',
#   'mississippi',
#   'revolves',
#   'around',
#   'the',
#   'help',
#   'yet',
#   'they',
#   'are',
#   'always',
#   'kept',
#   'certain',
#   'distance',
#   'because',
#   'racial',
#   'lines'],
#  ['chronicle',
#   'the',
#   'life',
#   'middle',
#   'class',
#   'french',
#   'girl',
#   'sexual',
#   'adventures',
#   'her',
#   'then',
#   'fall',
#   'into',
#   'prostitution',
#   'and',
#   'her',
#   'ultimate',
#   'redemption'],
#  ['the',
#   'winter',
#   '1982',
#   'twelve',
#   'man',
#   'research',
#   'team',
#   'remote',
#   'antarctic',
#   'research',
#   'station',
#   'discovers',
#   'alien',
#   'buried',
#   'the',
#   'snow',
#   'for',
#   'over',
#   '100',
#   '000',
#   'years',
#   'soon',
#   'unfrozen',
#   'the',
#   'form',
#   'changing',
#   'creature',
#   'wreaks',
#   'havoc',
#   'creates',
#   'terror',
#   'and',
#   'becomes',
#   'one',
#   'them'],
#  ['between',
#   'personal',
#   'obligations',
#   'and',
#   'training',
#   'for',
#   'his',
#   'next',
#   'big',
#   'fight',
#   'against',
#   'opponent',
#   'with',
#   'ties',
#   'his',
#   'family',
#   'past',
#   'adonis',
#   'creed',
#   'against',
#   'the',
#   'challenge',
#   'his',
#   'life'],
#  ['after',
#   'witnessing',
#   'brutal',
#   'murder',
#   'halloween',
#   'night',
#   'young',
#   'woman',
#   'becomes',
#   'the',
#   'next',
#   'target',
#   'maniacal',
#   'entity'],
#  ['thelma',
#   'dreams',
#   'being',
#   'glamorous',
#   'unicorn',
#   'then',
#   'rare',
#   'pink',
#   'and',
#   'glitter',
#   'filled',
#   'moment',
#   'fate',
#   'thelma',
#   'wish',
#   'comes',
#   'true',
#   'she',
#   'rises',
#   'instant',
#   'international',
#   'stardom',
#   'but',
#   'unexpected',
#   'cost',
#   'after',
#   'while',
#   'thelma',
#   'realizes',
#   'that',
#   'she',
#   'was',
#   'happier',
#   'her',
#   'ordinary',
#   'sparkle',
#   'free',
#   'self',
#   'she',
#   'ditches',
#   'her',
#   'horn',
#   'scrubs',
#   'off',
#   'her',
#   'sparkles',
#   'and',
#   'returns',
#   'home',
#   'where',
#   'her',
#   'best',
#   'friend',
#   'waiting',
#   'for',
#   'her',
#   'with',
#   'hug'],
#  ['the',
#   'guardians',
#   'must',
#   'fight',
#   'keep',
#   'their',
#   'newfound',
#   'family',
#   'together',
#   'they',
#   'unravel',
#   'the',
#   'mysteries',
#   'peter',
#   'quill',
#   'true',
#   'parentage'],
#  ['with',
#   'the',
#   'help',
#   'german',
#   'bounty',
#   'hunter',
#   'freed',
#   'slave',
#   'sets',
#   'out',
#   'rescue',
#   'his',
#   'wife',
#   'from',
#   'brutal',
#   'mississippi',
#   'plantation',
#   'owner'],
#  ['interpol',
#   'issued',
#   'red',
#   'notice',
#   'global',
#   'alert',
#   'hunt',
#   'and',
#   'capture',
#   'the',
#   'world',
#   'most',
#   'wanted',
#   'but',
#   'when',
#   'daring',
#   'heist',
#   'brings',
#   'together',
#   'the',
#   'fbi',
#   'top',
#   'profiler',
#   'and',
#   'two',
#   'rival',
#   'criminals',
#   'there',
#   'telling',
#   'what',
#   'will',
#   'happen'],
#  ['mark',
#   'hitman',
#   'haunted',
#   'his',
#   'past',
#   'corrupt',
#   'miami',
#   'cop',
#   'and',
#   'the',
#   'death',
#   'his',
#   'wife',
#   'and',
#   'son',
#   'prepares',
#   'for',
#   'his',
#   'next',
#   'killing',
#   'gradually',
#   'becomes',
#   'fascinated',
#   'the',
#   'beautiful',
#   'prostitute',
#   'who',
#   'lives',
#   'the',
#   'next',
#   'apartment',
#   'and',
#   'they',
#   'embark',
#   'passionate',
#   'affair',
#   'their',
#   'dreams',
#   'life',
#   'together',
#   'are',
#   'complicated',
#   'her',
#   'pimp',
#   'being',
#   'drugs',
#   'baron',
#   'before',
#   'they',
#   'can',
#   'escape',
#   'must',
#   'die',
#   'but',
#   'things',
#   'are',
#   'never',
#   'that',
#   'simple'],
#  ['the',
#   'classic',
#   'and',
#   'beloved',
#   'story',
#   'from',
#   'dr',
#   'seuss',
#   'now',
#   'cg',
#   'animated',
#   'film',
#   'from',
#   '20th',
#   'century',
#   'fox',
#   'animation',
#   'the',
#   'makers',
#   'the',
#   'ice',
#   'age',
#   'films',
#   'imaginative',
#   'elephant',
#   'named',
#   'horton',
#   'jim',
#   'carrey',
#   'hears',
#   'faint',
#   'cry',
#   'for',
#   'help',
#   'coming',
#   'from',
#   'tiny',
#   'speck',
#   'dust',
#   'floating',
#   'through',
#   'the',
#   'air',
#   'horton',
#   'suspects',
#   'there',
#   'may',
#   'life',
#   'that',
#   'speck',
#   'and',
#   'despite',
#   'surrounding',
#   'community',
#   'which',
#   'thinks',
#   'has',
#   'lost',
#   'his',
#   'mind',
#   'determined',
#   'save',
#   'the',
#   'tiny',
#   'particle',
#   'jim',
#   'carrey',
#   'and',
#   'steve',
#   'carell',
#   'lead',
#   'all',
#   'star',
#   'cast',
#   'bringing',
#   'this',
#   'wonderful',
#   'family',
#   'picture',
#   'life'],
#  ['the',
#   'former',
#   'world',
#   'heavyweight',
#   'champion',
#   'rocky',
#   'balboa',
#   'serves',
#   'trainer',
#   'and',
#   'mentor',
#   'adonis',
#   'johnson',
#   'the',
#   'son',
#   'his',
#   'late',
#   'friend',
#   'and',
#   'former',
#   'rival',
#   'apollo',
#   'creed'],
#  ['1630',
#   'farmer',
#   'relocates',
#   'his',
#   'family',
#   'remote',
#   'plot',
#   'land',
#   'the',
#   'edge',
#   'forest',
#   'where',
#   'strange',
#   'unsettling',
#   'things',
#   'happen',
#   'with',
#   'suspicion',
#   'and',
#   'paranoia',
#   'mounting',
#   'each',
#   'family',
#   'member',
#   'faith',
#   'loyalty',
#   'and',
#   'love',
#   'are',
#   'tested',
#   'shocking',
#   'ways'],
#  ['notorious',
#   'fighters',
#   'are',
#   'trapped',
#   'lethal',
#   'martial',
#   'arts',
#   'games',
#   'sadistic',
#   'magnate',
#   'armed',
#   'only',
#   'with',
#   'their',
#   'combat',
#   'skills',
#   'they',
#   'face',
#   'brutal',
#   'battles',
#   'for',
#   'survival',
#   'deadly',
#   'kill',
#   'killed',
#   'showdown'],
#  ['elite',
#   'old',
#   'fashioned',
#   'boarding',
#   'school',
#   'new',
#   'england',
#   'passionate',
#   'english',
#   'teacher',
#   'inspires',
#   'his',
#   'students',
#   'rebel',
#   'against',
#   'convention',
#   'and',
#   'seize',
#   'the',
#   'potential',
#   'every',
#   'day',
#   'courting',
#   'the',
#   'disdain',
#   'the',
#   'stern',
#   'headmaster'],
#  ['famed',
#   'monster',
#   'slayer',
#   'gabriel',
#   'van',
#   'helsing',
#   'dispatched',
#   'transylvania',
#   'assist',
#   'the',
#   'last',
#   'the',
#   'valerious',
#   'bloodline',
#   'defeating',
#   'count',
#   'dracula',
#   'anna',
#   'valerious',
#   'reveals',
#   'that',
#   'dracula',
#   'has',
#   'formed',
#   'unholy',
#   'alliance',
#   'with',
#   'dr',
#   'frankenstein',
#   'monster',
#   'and',
#   'hell',
#   'bent',
#   'exacting',
#   'centuries',
#   'old',
#   'curse',
#   'her',
#   'family'],
#  [],
#  ['successful',
#   'erotic',
#   'film',
#   'producer',
#   'from',
#   'rome',
#   'regularly',
#   'receives',
#   'letters',
#   'from',
#   'female',
#   'fans',
#   'seeking',
#   'his',
#   'advice',
#   'how',
#   'spice',
#   'their',
#   'sex',
#   'lives',
#   'thanks',
#   'his',
#   'years',
#   'experience',
#   'both',
#   'the',
#   'film',
#   'business',
#   'and',
#   'the',
#   'sex',
#   'industry',
#   'has',
#   'all',
#   'sorts',
#   'tips',
#   'the',
#   'ready',
#   'and',
#   'emergency',
#   'happy',
#   'make',
#   'house',
#   'call',
#   'himself',
#   'demonstrate',
#   'his',
#   'qualities',
#   'person'],
#  ['colin',
#   'macleod',
#   'hunts',
#   'for',
#   'the',
#   'man',
#   'responsible',
#   'for',
#   'the',
#   'death',
#   'his',
#   'love',
#   'chases',
#   'the',
#   'immortal',
#   'marcus',
#   'octavius',
#   'across',
#   'centuries',
#   'his',
#   'quest',
#   'threatens',
#   'take',
#   'over',
#   'his',
#   'life',
#   'and',
#   'heart',
#   'his',
#   'quest',
#   'meets',
#   'woman',
#   'who',
#   'reminds',
#   'him',
#   'his',
#   'slain',
#   'beauty',
#   'but',
#   'his',
#   'final',
#   'battle',
#   'with',
#   'marcus',
#   'that',
#   'will',
#   'decide',
#   'not',
#   'only',
#   'his',
#   'fate',
#   'but',
#   'also',
#   'the',
#   'fate',
#   'everyone',
#   'the',
#   'world'],
#  ['bonded',
#   'their',
#   'youth',
#   'and',
#   'separated',
#   'tragedy',
#   'astronaut',
#   'and',
#   'free',
#   'diver',
#   'bend',
#   'the',
#   'laws',
#   'space',
#   'and',
#   'time',
#   'their',
#   'efforts',
#   'together',
#   'again'],
#  ['dr',
#   'adrian',
#   'helmsley',
#   'part',
#   'worldwide',
#   'geophysical',
#   'team',
#   'investigating',
#   'the',
#   'effect',
#   'the',
#   'earth',
#   'radiation',
#   'from',
#   'unprecedented',
#   'solar',
#   'storms',
#   'learns',
#   'that',
#   'the',
#   'earth',
#   'core',
#   'heating',
#   'warns',
#   'u',
#   'president',
#   'thomas',
#   'wilson',
#   'that',
#   'the',
#   'crust',
#   'the',
#   'earth',
#   'becoming',
#   'unstable',
#   'and',
#   'that',
#   'without',
#   'proper',
#   'preparations',
#   'for',
#   'saving',
#   'fraction',
#   'the',
#   'world',
#   'population',
#   'the',
#   'entire',
#   'race',
#   'doomed',
#   'meanwhile',
#   'writer',
#   'jackson',
#   'curtis',
#   'stumbles',
#   'the',
#   'same',
#   'information',
#   'while',
#   'the',
#   'world',
#   'leaders',
#   'race',
#   'build',
#   'arks',
#   'escape',
#   'the',
#   'impending',
#   'cataclysm',
#   'curtis',
#   'struggles',
#   'find',
#   'way',
#   'save',
#   'his',
#   'family',
#   'meanwhile',
#   'volcanic',
#   'eruptions',
#   'and',
#   'earthquakes',
#   'unprecedented',
#   'strength',
#   'wreak',
#   'havoc',
#   'around',
#   'the',
#   'world'],
#  ['group',
#   'people',
#   'find',
#   'themselves',
#   'trapped',
#   'the',
#   'backwoods',
#   'west',
#   'virginia',
#   'fighting',
#   'for',
#   'their',
#   'lives',
#   'against',
#   'group',
#   'vicious',
#   'and',
#   'horribly',
#   'disfigured',
#   'inbred',
#   'cannibals'],
#  ...]

# %%
movies['Genres'] = movies['Genres'].apply(
    lambda x: [item.strip() for item in x] if isinstance(x, list) else x.split(',') if isinstance(x, str) else []
)

movies['Actors'] = movies['Actors'].apply(
    lambda x: [actor.strip() for actor in x.split(',')[:4]] if isinstance(x, str) else x if isinstance(x, list) else []
)

movies['Director'] = movies['Director'].apply(
    lambda x: [director.strip() for director in x.split(',')] if isinstance(x, str) else x if isinstance(x, list) else []
)

movies
# Out:
#              Original Title       ID  \
# 0                   Red One   845781
# 1     Venom: The Last Dance   912649
# 2      Sonic the Hedgehog 3   939243
# 3     Mufasa: The Lion King   762509
# 4                   Moana 2  1241982
# ...                     ...      ...
# 9995                Tomcats    10646
# 9996            Airport '77     7227
# 9997               Rye Lane  1049638
# 9998             胸が鳴るのは君のせい   803279
# 9999       Alex Strangelove   511785
#
#                                                  Genres  Adult  \
# 0                           [Action,  Fantasy,  Comedy]  False
# 1     [Action,  Science Fiction,  Adventure,  Thriller]  False
# 2          [Action,  Science Fiction,  Comedy,  Family]  False
# 3              [Adventure,  Family,  Drama,  Animation]  False
# 4             [Animation,  Adventure,  Family,  Comedy]  False
# ...                                                 ...    ...
# 9995                                 [Comedy,  Romance]  False
# 9996            [Action,  Adventure,  Drama,  Thriller]  False
# 9997                                 [Comedy,  Romance]  False
# 9998                                  [Romance,  Drama]  False
# 9999                                   [Comedy,  Drama]  False
#
#                                                Overview  Rating  \
# 0     After Santa Claus (codename: Red One) is kidna...    70.2
# 1     Eddie and Venom are on the run. Hunted by both...    68.0
# 2     Sonic, Knuckles, and Tails reunite against a p...    78.0
# 3     Told in flashbacks, Mufasa is an orphaned cub,...    71.0
# 4     After receiving an unexpected call from her wa...    69.4
# ...                                                 ...     ...
# 9995  College buddies chip in and promise that the g...    51.0
# 9996  Flight 23 has crashed in the Bermuda Triangle ...    55.9
# 9997  Two twenty-somethings, both reeling from bad b...    71.0
# 9998  When Tsukasa was a middle school student, she ...    75.0
# 9999  Alex Truelove is on a quest to lose his virgin...    65.8
#
#       Runtime (Seconds)                                             Actors  \
# 0                  7440  [Dwayne Johnson, Chris Evans, Lucy Liu, J.K. S...
# 1                  6540  [Tom Hardy, Chiwetel Ejiofor, Juno Temple, Cla...
# 2                  6600  [Ben Schwartz, Jim Carrey, Keanu Reeves, Idris...
# 3                  7080  [Aaron Pierre, Kelvin Harrison Jr., Tiffany Bo...
# 4                  6000  [Auliʻi Cravalho, Dwayne Johnson, Hualālai Chu...
# ...                 ...                                                ...
# 9995               5700  [Jerry O'Connell, Shannon Elizabeth, Jake Buse...
# 9996               6840  [Jack Lemmon, Lee Grant, Brenda Vaccaro, Josep...
# 9997               4920  [David Jonsson, Vivian Oparah, Poppy Allen-Qua...
# 9998               6240  [Ukisho Hidaka, Sei Shiraishi, Mizuki Itagaki,...
# 9999               5940  [Daniel Doheny, Madeline Weinstein, Antonio Ma...
#
#                                              Characters  \
# 0     Callum Drift, Jack O'Malley, Zoe, Nick, Mrs. C...
# 1     Eddie Brock / Venom, General Rex Strickland, D...
# 2     Sonic (voice), Dr. Robotnik / Gerald Robotnik,...
# 3     Mufasa (voice), Taka (voice), Sarabi (voice), ...
# 4     Moana (voice), Maui (voice), Moni (voice), Lot...
# ...                                                 ...
# 9995  Michael Delaney, Officer Natalie Parker, Kyle ...
# 9996  Don Gallagher, Karen Wallace, Eve Clayton, Nic...
# 9997                       Dom, Yas, Cass, Nathan, Eric
# 9998  Arima Hayato, Shinohara Tsukasa, Hasebe Yasuhi...
# 9999         Alex Truelove, Claire, Elliott, Dell, Josh
#
#                     Director Certification  \
# 0              [Jake Kasdan]         PG-13
# 1             [Kelly Marcel]         PG-13
# 2              [Jeff Fowler]            PG
# 3            [Barry Jenkins]            PG
# 4     [David G. Derrick Jr.]            PG
# ...                      ...           ...
# 9995       [Gregory Poirier]             R
# 9996         [Jerry Jameson]            PG
# 9997    [Raine Allen-Miller]             R
# 9998      [Hiroto Takahashi]     Not Rated
# 9999         [Craig Johnson]             R
#
#                                          clean_overview
# 0     [after, santa, claus, codename, red, one, kidn...
# 1     [eddie, and, venom, are, the, run, hunted, bot...
# 2     [sonic, knuckles, and, tails, reunite, against...
# 3     [told, flashbacks, mufasa, orphaned, cub, lost...
# 4     [after, receiving, unexpected, call, from, her...
# ...                                                 ...
# 9995  [college, buddies, chip, and, promise, that, t...
# 9996  [flight, 23, has, crashed, the, bermuda, trian...
# 9997  [two, twenty, somethings, both, reeling, from,...
# 9998  [when, tsukasa, was, middle, school, student, ...
# 9999  [alex, truelove, quest, lose, his, virginity, ...
#
# [10000 rows x 12 columns]

# %%
def clean(sentence):
    temp = []
    for word in sentence:
        temp.append(word.lower().replace(' ', ''))
    return temp

# %%
movies['Genres'] = [clean(x) for x in movies['Genres']]
movies['Actors'] = [clean(x) for x in movies['Actors']]
movies['Director'] = [clean(x) for x in movies['Director']]
movies
# Out:
#              Original Title       ID  \
# 0                   Red One   845781
# 1     Venom: The Last Dance   912649
# 2      Sonic the Hedgehog 3   939243
# 3     Mufasa: The Lion King   762509
# 4                   Moana 2  1241982
# ...                     ...      ...
# 9995                Tomcats    10646
# 9996            Airport '77     7227
# 9997               Rye Lane  1049638
# 9998             胸が鳴るのは君のせい   803279
# 9999       Alex Strangelove   511785
#
#                                              Genres  Adult  \
# 0                         [action, fantasy, comedy]  False
# 1     [action, sciencefiction, adventure, thriller]  False
# 2          [action, sciencefiction, comedy, family]  False
# 3             [adventure, family, drama, animation]  False
# 4            [animation, adventure, family, comedy]  False
# ...                                             ...    ...
# 9995                              [comedy, romance]  False
# 9996           [action, adventure, drama, thriller]  False
# 9997                              [comedy, romance]  False
# 9998                               [romance, drama]  False
# 9999                                [comedy, drama]  False
#
#                                                Overview  Rating  \
# 0     After Santa Claus (codename: Red One) is kidna...    70.2
# 1     Eddie and Venom are on the run. Hunted by both...    68.0
# 2     Sonic, Knuckles, and Tails reunite against a p...    78.0
# 3     Told in flashbacks, Mufasa is an orphaned cub,...    71.0
# 4     After receiving an unexpected call from her wa...    69.4
# ...                                                 ...     ...
# 9995  College buddies chip in and promise that the g...    51.0
# 9996  Flight 23 has crashed in the Bermuda Triangle ...    55.9
# 9997  Two twenty-somethings, both reeling from bad b...    71.0
# 9998  When Tsukasa was a middle school student, she ...    75.0
# 9999  Alex Truelove is on a quest to lose his virgin...    65.8
#
#       Runtime (Seconds)                                             Actors  \
# 0                  7440  [dwaynejohnson, chrisevans, lucyliu, j.k.simmons]
# 1                  6540  [tomhardy, chiwetelejiofor, junotemple, clarkb...
# 2                  6600   [benschwartz, jimcarrey, keanureeves, idriselba]
# 3                  7080  [aaronpierre, kelvinharrisonjr., tiffanyboone,...
# 4                  6000  [auliʻicravalho, dwaynejohnson, hualālaichung,...
# ...                 ...                                                ...
# 9995               5700  [jerryo'connell, shannonelizabeth, jakebusey, ...
# 9996               6840  [jacklemmon, leegrant, brendavaccaro, josephco...
# 9997               4920  [davidjonsson, vivianoparah, poppyallen-quarmb...
# 9998               6240  [ukishohidaka, seishiraishi, mizukiitagaki, na...
# 9999               5940  [danieldoheny, madelineweinstein, antoniomarzi...
#
#                                              Characters             Director  \
# 0     Callum Drift, Jack O'Malley, Zoe, Nick, Mrs. C...         [jakekasdan]
# 1     Eddie Brock / Venom, General Rex Strickland, D...        [kellymarcel]
# 2     Sonic (voice), Dr. Robotnik / Gerald Robotnik,...         [jefffowler]
# 3     Mufasa (voice), Taka (voice), Sarabi (voice), ...       [barryjenkins]
# 4     Moana (voice), Maui (voice), Moni (voice), Lot...  [davidg.derrickjr.]
# ...                                                 ...                  ...
# 9995  Michael Delaney, Officer Natalie Parker, Kyle ...     [gregorypoirier]
# 9996  Don Gallagher, Karen Wallace, Eve Clayton, Nic...       [jerryjameson]
# 9997                       Dom, Yas, Cass, Nathan, Eric  [raineallen-miller]
# 9998  Arima Hayato, Shinohara Tsukasa, Hasebe Yasuhi...    [hirototakahashi]
# 9999         Alex Truelove, Claire, Elliott, Dell, Josh       [craigjohnson]
#
#      Certification                                     clean_overview
# 0            PG-13  [after, santa, claus, codename, red, one, kidn...
# 1            PG-13  [eddie, and, venom, are, the, run, hunted, bot...
# 2               PG  [sonic, knuckles, and, tails, reunite, against...
# 3               PG  [told, flashbacks, mufasa, orphaned, cub, lost...
# 4               PG  [after, receiving, unexpected, call, from, her...
# ...            ...                                                ...
# 9995             R  [college, buddies, chip, and, promise, that, t...
# 9996            PG  [flight, 23, has, crashed, the, bermuda, trian...
# 9997             R  [two, twenty, somethings, both, reeling, from,...
# 9998     Not Rated  [when, tsukasa, was, middle, school, student, ...
# 9999             R  [alex, truelove, quest, lose, his, virginity, ...
#
# [10000 rows x 12 columns]

# %%
# Combining all the data into a single list
columns = ['clean_overview','Genres','Actors','Director']

l = []

for i in range(len(movies)):
    words =''
    for col in columns:
#  'bonded their youth and separated tragedy astronaut and free diver bend the laws space and time their efforts together again romance drama sciencefiction sarochachankimha rebeccapatriciaarmstrong torfantaweema siriampakdeedumrongrit thanadolnuansut ',
#  'dr adrian helmsley part worldwide geophysical team investigating the effect the earth radiation from unprecedented solar storms learns that the earth core heating warns u president thomas wilson that the crust the earth becoming unstable and that without proper preparations for saving fraction the world population the entire race doomed meanwhile writer jackson curtis stumbles the same information while the world leaders race build arks escape the impending cataclysm curtis struggles find way save his family meanwhile volcanic eruptions and earthquakes unprecedented strength wreak havoc around the world action adventure sciencefiction johncusack amandapeet chiwetelejiofor thandiwenewton rolandemmerich ',
#  "group people find themselves trapped the backwoods west virginia fighting for their lives against group vicious and horribly disfigured inbred cannibals horror thriller tomfrederic janetmontgomery louisecliffe jackgordon declano'brien ",
#  ...]

# %%
movies['clean_overview'] = l
movies = movies[['Original Title','clean_overview']]
movies.head()
# Out:
#           Original Title                                     clean_overview
# 0                Red One  after santa claus codename red one kidnapped t...
# 1  Venom: The Last Dance  eddie and venom are the run hunted both their ...
# 2   Sonic the Hedgehog 3  sonic knuckles and tails reunite against power...
# 3  Mufasa: The Lion King  told flashbacks mufasa orphaned cub lost and a...
# 4                Moana 2  after receiving unexpected call from her wayfi...

# %%
##  Feature Extraction

from sklearn.feature_extraction.text import TfidfVectorizer

tfidf = TfidfVectorizer()
features = tfidf.fit_transform(movies['clean_overview'])

# %%
# Similarity Matrix using cosine similarity
from sklearn.metrics.pairwise import cosine_similarity
similarity = cosine_similarity(features,features)
print(similarity)
# Out:
# [[1.         0.01921062 0.03953509 ... 0.00856931 0.         0.01203546]
#  [0.01921062 1.         0.02684518 ... 0.03058611 0.01430265 0.01818551]
#  [0.03953509 0.02684518 1.         ... 0.01759677 0.0021778  0.01422896]
#  ...
#  [0.00856931 0.03058611 0.01759677 ... 1.         0.00592633 0.00719762]
#  [0.         0.01430265 0.0021778  ... 0.00592633 1.         0.00568237]
#  [0.01203546 0.01818551 0.01422896 ... 0.00719762 0.00568237 1.        ]]

# %%
## Movie Recommendation

index = pd.Series(movies['Original Title'])
index.head(5)
# Out:
# 0                  Red One
# 1    Venom: The Last Dance
# 2     Sonic the Hedgehog 3
# 3    Mufasa: The Lion King
# 4                  Moana 2
# Name: Original Title, dtype: object

# %%
## Recommendation Function

def recommend_movies(title):
    title = title.lower() 
    matching_indices = index[index.str.lower() == title].index  # Match the title in lowercase

    if len(matching_indices) == 0:
        print(f"Movie '{title}' not found in the dataset.")
        return []

    idx = matching_indices[0]
    print(f"Found movie at index {idx}.")

    # Compute similarity scores
    score = pd.Series(similarity[idx]).sort_values(ascending=False)

    # Get top 10 recommended movie indices (excluding the input movie itself)
    top10_indices = score.index[1:11]  # Exclude the first index (the input movie itself)

    # Retrieve movie titles for recommendations
    recommended_movies = []
    for i in top10_indices:
        recommended_movies.append(movies['Original Title'][i])

    return recommended_movies

# %%
recommend_movies('red one')
# Out:
# Found movie at index 0.
# ['The Snowman',
#  'Fred Claus',
#  'Arthur Christmas',
#  'The Christmas Chronicles: Part Two',
#  'Santa Claus: The Movie',
#  'Saving Santa',
#  'Jumanji: The Next Level',
#  'The Santa Clause 2',
#  'The Santa Clause 3: The Escape Clause',
#  'Get Santa']
